# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
#PCA_v1 = np.load("specie_6_PCA_v1.npy")
PCA_v2 = np.load("specie_6_PCA_v2.npy")

# %%
#plt.scatter(PCA_v1[:,0],PCA_v1[:,1],s=0.1,label="v1")
plt.scatter(PCA_v2[:,0],PCA_v2[:,1],s=0.1,label="v2")
plt.legend(markerscale=10)

# %%
PCoV_v1 = np.load("specie_1_PCov_v1.npy")
PCoV_v2 = np.load("specie_1_PCov_v2.npy")

# %%
#plt.scatter(PCoV_v1[:,0],PCoV_v1[:,1],s=0.1,label="v1")
plt.scatter(PCoV_v2[:,0],PCoV_v2[:,1],s=0.1,label="v2")
#plt.xlim(-1,5)
plt.legend(markerscale=10)
