# %%
from rascal.neighbourlist.structure_manager import mask_center_atoms_by_species
from ase.io import read
from rascal.representations import SphericalInvariants
from rascal.utils import get_optimal_radial_basis_hypers
import numpy as np
from helpers import *

# %%
PATH_TRAIN = "./make_tensor_data/train_tensor/CSD-3k+S546_shift_tensors.xyz"

structures_train = read(PATH_TRAIN,format="extxyz",index=":100")

for structure in structures_train: mask_center_atoms_by_species(structure,species_select=[1])
for structure in structures_train: structure.wrap(eps=1e-12)

structures_train = filter_by_status(structures_train,status="PASSING")

# %%
s

# %%
indices_filtered = np.load("selected_sample_ids_H_n8_l5_PASSING.npy")

# %%
this = return_relative_inds(structures_train, indices_filtered, 1)

# %%
for i in this:
    print(i)
# Out:
# ['PYRIDO04' '28']
# ['NIPLED' '36']
# ['COVSEM' '42']
# ['IBPRAC14' '91']
# ['CUPZIY' '57']
# ['AXOBAS' '6']
# ['ODOHIA' '90']
# ['MFZCHZ' '29']
# ['TSCARB01' '42']
# ['LESLAX' '64']
# ['RIHJIB' '120']
# ['AHIMOU' '79']
# ['BUGKOE' '8']
# ['QUDNAG' '62']
# ['KEBGAB02' '7']
# ['FOWDAY' '67']
# ['SERVOA' '38']
# ['HAXTAD' '121']
# ['CTMTNA06' '60']
# ['COXZEU' '39']
# ['IFIZIG09' '34']
# ['XEPNUD' '53']
# ['SUCROS27' '32']
# ['ZAQHAC' '102']
# ['EFARIO' '92']
# ['ZZZNWQ01' '69']
# ['EJIQEU02' '24']
# ['VOQXAA' '70']
# ['FOXJIN' '66']
# ['QUDNAG' '45']
# ['FOYNEO01' '107']
# ['QOYJOD06' '34']
# ['IKABIG' '62']
# ['LEMSIF' '104']
# ['JIWZAQ' '85']
# ['COFHOW' '101']
# ['ROZPUT' '32']
# ['LOXBAD' '61']
# ['MILYIP' '9']
# ['HAWYIN' '53']
# ['QEKXUZ' '21']
# ['FONMEB' '13']
# ['LEFJEM' '57']
# ['XIBZOX' '39']
# ['EROFEX' '16']
# ['BCBANN06' '59']
# ['CABCUD15' '11']
# ['KEPFOC' '92']
# ['LAPSIG' '68']
# ['CUPZEU' '43']
# ['VECXIL' '34']
# ['SIDKOG' '82']
# ['MESCZA' '19']
# ['VISDIK' '6']
# ['DTURAC01' '21']
# ['LINKAW' '166']
# ['XEWKAN' '138']
# ['LUYJIZ' '67']
# ['KECYBU02' '8']
# ['MISGAX' '33']
# ['NSBTOA' '56']
# ['ZEXYOQ' '75']
# ['GAKXAT' '36']
# ['QOPKUB' '31']
# ['WIGBOE' '71']
# ['MMXPDZ10' '40']
# ['DOMQUS' '29']
# ['KUTHAI' '106']
# ['VEHCUG' '149']
# ['CADBOB' '61']
# ['FAHYOC' '65']
# ['LUKCIF' '63']
# ['KAXWOW' '58']
# ['CITSED10' '28']
# ['CIWMAW01' '59']
# ['UJULIU' '12']
# ['CITSED10' '58']
# ['HUQRAM' '91']
# ['IFIZIG09' '118']
# ['EHAXOB' '6']
# ['FEDNUY' '19']
# ['NUPTIC' '31']
# ['YECVUX' '21']
# ['LEGLEQ' '89']
# ['RAYXUK' '37']
# ['DOJLAQ' '17']
# ['XOZHEZ' '63']
# ['ATOXAL03' '44']
# ['XIWBAI' '11']
# ['WETGAE' '15']
# ['TIPVIZ' '61']
# ['AMACAM01' '31']
# ['NAYKOO' '90']
# ['ONAVEF' '71']
# ['YOTYOW' '13']
# ['WAPPUY' '97']
# ['DIRMIA' '13']
# ['SUSYAI' '58']
# ['NUQTOJ' '83']
# ['HUMNEI' '109']
# ['YUWGOO' '91']
# ['IBUWAD' '89']
# ['ADMNTB04' '58']
# ['BETBEH10' '43']
# ['GEJCIJ' '74']
# ['DIHRUH10' '52']
# ['WUHYIH' '33']
# ['CARCAZ' '161']
# ['WAZDEG' '111']
# ['CABCUD15' '16']
# ['KUZWUY' '59']
# ['XIXQUR' '27']
# ['DIALAC02' '33']
# ['YEHPIK' '46']
# ['CAFVUA' '46']
# ['XIHLIL' '20']
# ['EFOTEY' '43']
# ['ZAJGUM' '130']
# ['DELMOX' '29']
# ['GAQSEY' '11']
# ['QIYRIZ' '27']
# ['AJIGAB' '35']
# ['PRMDIN20' '15']
# ['LEFLUE' '30']
# ['DACETA11' '45']
# ['MAPZAF' '51']
# ['GLYCIN52' '18']
# ['VAYLAI' '49']
# ['LEJPAS' '38']
# ['TILJUV' '35']
# ['BONKOE' '82']
# ['BICMAD' '15']
# ['DATFIO' '56']
# ['KEPFOC' '120']
# ['SUMKIU' '74']
# ['QISQEP' '97']
# ['DAZDOZ' '129']
# ['VABLIT' '132']
# ['AHEYAO' '131']
# ['GEJCEF' '78']
# ['XIHLIL' '47']
# ['VABLIT' '141']
# ['EGAFAU' '101']
# ['DODCHD' '52']
# ['MAMVUS' '23']
# ['POXWEE' '54']
# ['HXOXAM10' '73']
# ['LOWBIK' '51']
# ['SALOXM09' '62']
# ['BUKVAE' '58']
# ['UREAXX27' '27']
# ['XAHLOJ' '28']
# ['CITSED10' '27']
# ['LUDFAR' '40']
# ['ECAGIA' '2']
# ['TAHHOC' '20']
# ['SABMAL' '133']
# ['DIQCEN' '64']
# ['CTMTNA06' '73']
# ['HOQHUQ' '114']
# ['YEKJEF' '35']
# ['HYDRZN11' '56']
# ['NACXEU01' '78']
# ['EBUKUH' '26']
# ['IFUWIR' '38']
# ['ESOYUI' '17']
# ['IGAMEJ' '68']
# ['XUBLEN' '34']
# ['COXXUJ' '30']
# ['HILVOO01' '26']
# ['VUYWUH' '36']
# ['BIMSAR' '110']
# ['XOJKAK' '67']
# ['UJULIU' '58']
# ['QUVFIX' '11']
# ['SITQET' '68']
# ['AKEZIB05' '2']
# ['DOZNOV' '62']
# ['UQALUU' '70']
# ['GOKFUJ' '103']
# ['TROPOL10' '28']
# ['NIRJEE04' '50']
# ['WAJPUV' '87']
# ['HOZPET01' '53']
# ['DOXXAP' '43']
# ['ICAKEC' '63']
# ['QIGVAD' '87']
# ['MAYWIU' '42']
# ['IBOLUG' '20']
# ['MOHCUI' '88']
# ['ODOHIA' '26']
# ['LETDUJ' '47']
# ['QAGDAG' '43']
# ['DAJVUG01' '128']
# ['NADYUM' '2']
# ['QILZIU' '90']
# ['UFAWUV' '2']
# ['HNIMOZ' '44']
# ['VUWXIU' '64']
# ['GISYEO' '56']
# ['HOQCOF' '118']
# ['KULMUA' '49']
# ['QIPPUA' '107']
# ['EFOQOG' '46']
# ['DUWRIW' '86']
# ['RONVEV' '43']
# ['HMALAC01' '34']
# ['SAGRUN' '26']
# ['ZEXYOQ' '84']
# ['CEKBAX' '85']
# ['OKAVAY' '68']
# ['FOGJAM' '31']
# ['QIQCUQ' '4']
# ['BECYAL' '135']
# ['LOHQAA' '27']
# ['LEGLEQ' '150']
# ['VINXEW' '45']
# ['QIYRIZ' '24']
# ['NAKVUT' '142']
# ['KENMOF' '124']
# ['XIHLIL' '95']
# ['GEJCAB' '58']
# ['ACOWIY' '66']
# ['IFIZIG09' '112']
# ['HEQWOR' '24']
# ['XAZDUY' '25']
# ['UJIRUC' '71']
# ['GILCIP' '80']
# ['AZALIX' '74']
# ['TAPBAP' '72']
# ['FURDCB01' '50']
# ['EFOQOG' '21']
# ['ZIBBAP' '50']
# ['XUDTIB' '84']
# ['SOLHAD' '97']
# ['NMALAM01' '47']
# ['KIZCUT' '75']
# ['ATOMAY' '31']
# ['LEVXOB' '15']
# ['OTAKEB' '64']
# ['ETDIAM17' '20']
# ['CBOHAZ02' '36']
# ['HEWKAW' '137']
# ['ASOPEF' '124']
# ['PUKGIN' '38']
# ['KIJNUM' '123']
# ['VOTMEY' '23']
# ['DATFIO' '70']
# ['WIDJOI' '106']
# ['OMIZOB' '58']
# ['VAZBUV' '43']
# ['NUPTIC' '21']
# ['ITIPEG' '168']
# ['GENZEF' '47']
# ['EPAHEJ' '55']
# ['KICCOO11' '162']
# ['MPYDCX' '27']
# ['XOCZUL' '120']
# ['NIRJEE04' '60']
# ['KISJEC' '146']
# ['NOHTAZ' '83']
# ['FOWQOY' '98']
# ['KIZCUT' '81']
# ['ISAJUH' '95']
# ['DZCDON' '17']
# ['EGAFAU' '141']
# ['CALVAM' '56']
# ['XIHLIL' '91']
# ['TAHGUE' '83']
# ['AMSALA02' '7']
# ['UHIQOS' '19']
# ['TIJKEC' '22']
# ['XOCJEE' '25']
# ['FEHVEU' '39']
# ['LUNYID' '92']
# ['QEHDEO' '78']
# ['VABLIT' '160']
# ['BOVLEF' '37']
# ['BATWUO' '134']
# ['XUPGAQ' '71']
# ['QEDFOW' '66']
# ['TRIRED' '17']
# ['ILABEE' '93']
# ['CIGGAC' '11']
# ['MOHCUI' '30']
# ['ZIYZEM' '85']
# ['SUCROS27' '13']
# ['NIQPOT02' '74']
# ['BISMEV10' '38']
# ['FOWQOY' '31']
# ['QUDNOU' '102']
# ['EKUJIF' '42']
# ['GLYCIN81' '11']
# ['MERPUM' '115']
# ['DEHYUM' '131']
# ['JUVMUI' '48']
# ['PUHJAE' '9']
# ['CABCUD15' '44']
# ['CAGJEC01' '5']
# ['TALTIK' '121']
# ['HYDRZN11' '66']
# ['FOPDUL' '78']
# ['FEZRAD' '46']
# ['TIQROC' '105']
# ['WEGSIL' '132']
# ['KURRIY01' '114']
# ['UJIBAR' '32']
# ['YIZXOV' '10']
# ['DATFIO' '52']
# ['PYZPYT01' '93']
# ['FIHNIV' '34']
# ['RUPMEW' '129']
# ['TALTIK' '61']
# ['MOGYOX' '18']
# ['ELEYOJ' '81']
# ['BEHBIA' '79']
# ['VAVHEH' '33']
# ['UXUKII' '37']
# ['QONRAO' '64']
# ['IGAMEJ' '8']
# ['NAYPAF' '102']
# ['FEFLEI' '48']
# ['MODCUD' '53']
# ['FOYGIL' '21']
# ['HABFUL' '73']
# ['CECQAD' '53']
# ['RABVIC' '57']
# ['CITSED10' '57']
# ['QONRAN' '18']
# ['OXAZDO' '67']
# ['KIJNUM' '106']
# ['QOXMUM' '70']
# ['FATZEH' '107']
# ['VUWXIU' '120']
# ['KICCOO11' '92']
# ['FADBOB' '112']
# ['GEHPUE' '61']
# ['XAGDOY' '61']
# ['HAJVOE' '109']
# ['ITIPEG' '17']
# ['YARYAS' '83']
# ['NITPUB' '123']
# ['ZAPGII' '72']
# ['EFUMAU02' '26']
# ['CUPZEU' '49']
# ['TEOXDE01' '12']
# ['IZAWUB' '60']
# ['ISEDOB' '94']
# ['ACOGAA' '65']
# ['CAFMIF' '12']
# ['HORZAQ' '22']
# ['VAVHEH' '31']
# ['NOSLEM' '101']
# ['IMEGIR09' '77']
# ['COWSOY' '39']
# ['VAVHEH' '51']
# ['TIMFUS' '80']
# ['RELLAV' '86']
# ['QOBGUL' '36']
# ['QAHPIZ' '46']
# ['QIJDES' '8']
# ['AMACAM01' '58']
# ['CASCIJ01' '73']
# ['ATZTHD10' '50']
# ['XAZDUY' '42']
# ['LSERMH15' '40']
# ['KIYQUF' '41']
# ['OVAYAM' '130']
# ['ECAGIA' '24']
# ['BUFMOG' '56']
# ['CASYIG' '30']
# ['UQAFEZ' '18']
# ['QOQGOT' '41']
# ['COXXUJ' '36']
# ['LSERIN21' '16']
# ['CYSTAC08' '51']
# ['QAKKOE' '3']
# ['UGEBOZ' '47']
# ['BUHYEI' '54']
# ['JIZFAZ' '66']
# ['KEPSED' '81']
# ['LUZFUJ' '25']
# ['LABJON01' '39']
# ['VEZCAE' '87']
# ['FIZDIB' '30']
# ['TILJUV' '52']
# ['NIFDAI' '8']
# ['QACZEB' '118']
# ['BAKFUO' '37']
# ['UNURUS' '45']
# ['DILSEY' '26']
# ['JIQZOY01' '21']
# ['RUHGEI' '69']
# ['ENOBEP' '62']
# ['YANREM01' '23']
# ['AHICIF01' '14']
# ['NICOAM06' '46']
# ['NUYMUQ' '130']
# ['FOWDAY' '86']
# ['NEXSIU' '38']
# ['BEXSAY' '39']
# ['PEJVOQ' '66']
# ['ZEXYOQ' '30']
# ['SARBUI' '106']
# ['NUMBII' '2']
# ['DACLOL' '172']
# ['JAGMEM' '5']
# ['OKAVAY' '65']
# ['CECQAD' '38']
# ['NABKIN' '115']
# ['AJUXEI' '8']
# ['SALOXM09' '40']
# ['GELWOL' '47']
# ['QIJDES' '43']
# ['FUYJIS' '32']
# ['UDURUH' '58']
# ['RAYLAE' '131']
# ['BIZBET' '80']
# ['LEGLEQ' '159']
# ['BONKOE' '74']
# ['BONGIW' '64']
# ['QAJQAV' '59']
# ['MOHCUI' '53']
# ['KEMZIL01' '24']
# ['TEZCOR' '75']
# ['FAHYOC' '56']
# ['UPIKUB' '6']
# ['MACTUH' '53']
# ['USUWOW' '44']
# ['SIDKOG' '79']
# ['VEXGOU' '69']
# ['CIWWAI' '134']
# ['KAFLEI' '169']
# ['WONFUB' '69']
# ['LUZFUJ' '16']
# ['XAVPOZ01' '22']
# ['SIGFEU' '108']
# ['MAYXEP' '75']
# ['HIVGAW' '51']
# ['ZZZNWQ01' '86']
# ['LULLAG' '136']
# ['LADLOT' '108']
# ['DATQAR' '24']
# ['CAZDIS' '120']
# ['HEMLAM' '21']
# ['PYRGAL03' '52']
# ['TUJKIT' '63']
# ['WOMYEC' '24']
# ['FAYBUC' '168']
# ['QAGRIC' '21']
# ['CUPZEU' '32']
# ['PEVSIS' '33']
# ['QONRUI' '86']
# ['FEKVOG' '150']
# ['EKUJUR' '39']
# ['WACJIT' '53']
# ['CEKVIX' '30']
# ['BIBVAK' '27']
# ['LCYSTN25' '53']
# ['YIHJOP' '64']
# ['ZENMUA' '55']
# ['NTRGUA01' '112']
# ['NISMIL' '105']
# ['NIWCAY' '2']
# ['PEDERL' '23']
# ['DOHDEJ' '80']
# ['TEMDOG' '12']
# ['WUJQEY' '28']
# ['CITVIL' '28']
# ['XOJHOU' '19']
# ['QOQGOT' '16']
# ['TAHNEV' '72']
# ['SOLHAD' '102']
# ['CAZDOY' '76']
# ['DATFIO' '67']
# ['ZEBYEM' '3']
# ['FIYZAO' '72']
# ['NMHXNT' '49']
# ['IZAWUB' '21']
# ['HUKRUA' '2']
# ['DUVFUV02' '183']
# ['NIQVAL' '97']
# ['LORJAD' '150']
# ['CEWGUH' '46']
# ['QUDPOW' '31']
# ['VOBDOF' '151']
# ['ZZZNWQ01' '33']
# ['LONRAI' '63']
# ['SIXXON' '53']
# ['KUTHAI' '152']
# ['XAYYUS' '87']
# ['AMPTOP10' '70']
# ['KOJZUE' '195']
# ['OCIBIL' '24']
# ['METAMI' '40']
# ['REVMIP' '7']
# ['DISBUE' '41']
# ['NBFURX' '75']
# ['CAKXAO' '82']
# ['GACSUB' '24']
# ['DIQCAJ' '25']
# ['AYUBUS' '6']
# ['NESTIP' '53']
# ['TENZOD' '48']
# ['ANUREH' '4']
# ['YINDUU' '111']
# ['KIXCUP' '52']
# ['BALNIN04' '40']
# ['JUPVAR' '61']
# ['KAKQAO' '66']
# ['XACSOL' '87']
# ['IMEGIR09' '38']
# ['TIJKEC' '10']
# ['CACHAP' '116']
# ['IVEZEO' '112']
# ['AGUSEB' '52']
# ['HEHQOC' '24']
# ['EKUJIF' '25']
# ['WEVVOJ01' '83']
# ['HIZTEQ' '12']
# ['KOVHOS' '137']
# ['NIJHUJ' '21']
# ['NIPLED' '34']
# ['PUSZOU' '145']
# ['NUPTIC' '40']
# ['APENUG' '105']
# ['MTETAC01' '39']
# ['OFUKOR' '69']
# ['VIPKIO03' '40']
# ['HACMUT' '54']
# ['TORTEZ' '86']
# ['ROGVIU' '114']
# ['FURDCB01' '57']
# ['GOKNOK' '69']
# ['VIZWAE' '62']
# ['UHUMEP01' '36']
# ['FAFKEC' '109']
# ['DOTTUB' '31']
# ['HOQHUQ' '81']
# ['MACNHS' '138']
# ['TCHYZS' '38']
# ['XIBZOX' '40']
# ['CIKXOJ' '73']
# ['EXUQAP' '119']
# ['WEWRAR' '14']
# ['DOVDIC' '72']
# ['CUZJOY' '38']
# ['QOPKUB' '160']
# ['FOWTER' '33']
# ['NIRJEE04' '45']
# ['IFIZIG09' '95']
# ['SIGBOZ' '41']
# ['MEGLAN01' '31']
# ['QUFPEO' '154']
# ['SICSEC' '87']
# ['XEBTEF' '6']
# ['GOKFUJ' '105']
# ['ZIXPAZ' '60']
# ['ZDGLPN' '122']
# ['IKABIG' '61']
# ['NIRJEE04' '52']
# ['YOTYOW' '49']
# ['FUTLEN' '50']
# ['ROBYAI' '162']
# ['SOWREB' '118']
# ['YASSIV' '84']
# ['DIQCAJ' '18']
# ['YUWGOO' '50']
# ['DHURAC10' '25']
# ['DUVYEZ02' '4']
# ['VOPJEP' '26']
# ['IHINEU' '25']
# ['CITSED10' '24']
# ['TILJOP' '62']
# ['IPUMAH' '70']
# ['CAZBAI' '99']
# ['LAJGUA' '187']
# ['QOXMUM' '152']
# ['YATGIL' '131']
# ['RIZZEH' '71']
# ['LAPSIG' '57']
# ['LORJAD' '142']
# ['HAJVOE' '130']
# ['SOJHEE' '75']
# ['TEJPEE' '86']
# ['JEPPEZ' '74']
# ['JUNQIS' '62']
# ['VOHXIB' '81']
# ['RUWRAC' '46']
# ['NEWYIX' '43']
# ['TIGBIU' '58']
# ['NICOAM06' '36']
# ['KADMIO' '25']
# ['NESTIP' '3']
# ['YITKIX' '24']
# ['BEVYOS' '29']
# ['FORMAM03' '28']
# ['QUBRAH' '29']
# ['GACSUB' '76']
# ['POVKIW' '41']
# ['NIGNOH' '37']
# ['ISOMUS' '78']
# ['TESKUZ' '18']
# ['NUVXIM' '63']
# ['HAMCIJ' '191']
# ['ADEWUC' '81']
# ['FUTFIJ' '25']
# ['UVEGIN' '54']
# ['EFOQOG' '94']
# ['FORMAM03' '43']
# ['JESNAX' '19']
# ['BICMAD' '26']
# ['AFIMOT' '62']
# ['KOVGOR' '32']
# ['VOHCEC' '97']
# ['OJIVOU01' '79']
# ['WOCQEK' '24']
# ['IMUWIX' '36']
# ['YANWAN' '44']
# ['PIDHIU' '25']
# ['ZIYGUL' '123']
# ['XUPGAQ' '99']
# ['FOACAM' '97']
# ['MUQHOW' '35']
# ['NOLDUP' '124']
# ['VODWIU' '120']
# ['FUNVAL' '28']
# ['KUQTEX' '46']
# ['EJEQUF' '49']
# ['QALWOR' '37']
# ['OJUMOX' '72']
# ['WETGAE' '19']
# ['GENZEF' '61']
# ['JUPVAR' '70']
# ['DODCHD' '63']
# ['UJULIU' '25']
# ['LIQPEH' '25']
# ['OBUWOA' '58']
# ['KAMFAH' '18']
# ['CINSOH' '73']
# ['ILOFIA' '46']
# ['POWBAE' '173']
# ['HAJVOE' '43']
# ['CYSTAC08' '53']
# ['OGIQEB' '12']
# ['IPABUX' '14']
# ['VUHDEJ' '21']
# ['FOZLIQ' '62']
# ['WAWWAU' '110']
# ['AXACEI01' '124']
# ['NINZIV' '48']
# ['HMTOFA07' '109']
# ['ROGDIB' '88']
# ['DIQCEN' '76']
# ['NUYJEW' '76']
# ['UWOSAC' '94']
# ['ATDZSA04' '53']
# ['QIRRUG' '73']
# ['EWADOX' '11']
# ['XIDQIL' '25']
# ['CITSED10' '23']
# ['NIJHUJ' '53']
# ['TOCLUU' '34']
# ['JOHKIC' '130']
# ['HAVSEC' '90']
# ['CBOHAZ04' '31']
# ['GAKXAT' '74']
# ['TEDNIB' '48']
# ['JOPNOR' '102']
# ['YEFDOE' '79']
# ['GIRRUV' '51']
# ['RUYSUZ' '42']
# ['LEFJEM' '52']
# ['TAVXOF' '87']
# ['FIZHAX' '69']
# ['HMNCXC01' '117']
# ['BEJTAL' '148']
# ['ACIDOH' '50']
# ['MPYDCX' '28']
# ['QOLRIT' '9']
# ['AGLYSL' '29']
# ['OHOYUH' '71']
# ['GULHAW' '42']
# ['KUDWEN' '24']
# ['TEVJIP01' '53']
# ['PIKYEN' '26']
# ['NEXSIU' '21']
# ['CIVVEI10' '113']
# ['LETDUJ' '30']
# ['VATJIK' '106']
# ['WEWPUJ' '109']
# ['FAHYOC' '91']
# ['YOTYOW' '82']
# ['IVALUO' '186']
# ['NEQWEN' '37']
# ['MOHCUI' '78']
# ['VAMJOJ' '54']
# ['CUMBUH' '97']
# ['VOTMEY' '29']
# ['SEPNUX' '51']
# ['PYRZAL10' '13']
# ['KUZWOS' '96']
# ['VIPKIO03' '24']
# ['CASYIG' '68']
# ['DUFBOV11' '23']
# ['IFIZIG09' '32']
# ['NAPDCX' '37']
# ['KOJZUE' '180']
# ['HOCWAX' '69']
# ['BAGFIY01' '34']
# ['TALHET' '111']
# ['EGAFAU' '58']
# ['TIHJEA' '89']
# ['KUFDUK' '178']
# ['XOKVIE' '143']
# ['WAZDEG' '61']
# ['WAJPUV' '61']
# ['LANYAA' '50']
# ['KOHPUT' '74']
# ['WOLGIN' '75']
# ['VIHTUD' '21']
# ['QAFFOS' '51']
# ['LUVPEY' '62']
# ['CECWAK' '2']
# ['MAJTEX' '135']
# ['HARJIV01' '38']
# ['PUHHOQ' '52']
# ['INEZIM' '62']
# ['CAZDIS' '99']
# ['MUGNUX' '42']
# ['TIMWAN' '108']
# ['TEJPEE' '95']
# ['DMETSO06' '14']
# ['MUCCOD' '103']
# ['AMSALA02' '55']
# ['WAVXIA' '171']
# ['NURQEW' '34']
# ['NESTIP' '34']
# ['TIJKEC' '26']
# ['NUYJEW' '85']
# ['ECUXUW' '69']
# ['NUQPOF' '100']
# ['EXIGOI' '128']
# ['EHIXOI' '41']
# ['UVIZEG' '33']
# ['QAHCUA' '92']
# ['CAHOAM' '8']
# ['IKASUK' '93']
# ['BUFMOG' '44']
# ['RUPMEW' '74']
# ['EFUMEY' '6']
# ['TOLCAY02' '21']
# ['IFIZIG09' '51']
# ['QIJDES' '30']
# ['SIDKOG' '93']
# ['PEBTAU04' '111']
# ['CEKTOB' '72']
# ['FUSFAB' '128']
# ['GACSUB' '70']
# ['BABFUI' '107']
# ['BOQQUT08' '44']
# ['YEKHIH' '49']
# ['XAGDOY' '51']
# ['WAKNUS' '93']
# ['AZASER11' '67']
# ['YAXHUC' '107']
# ['KOWRUJ' '4']
# ['HEMLAM' '19']
# ['QAHCUA' '96']
# ['XOJHOU' '69']
# ['DAPJUA' '148']
# ['YUZTET' '34']
# ['TOMBAA' '49']
# ['SESQIR' '85']
# ['KAMFAH' '33']
# ['QQQFCY01' '173']
# ['YODHUV' '137']
# ['IMICOW' '65']
# ['JOHKIC' '111']
# ['ELEYOJ' '89']
# ['ZDGLPN' '125']
# ['ZEBYEM' '18']
# ['APITIE' '45']
# ['BUTGAA' '17']
# ['NICOAM06' '50']
# ['QADBAY' '65']
# ['CUTTOB' '101']
# ['PODFIZ' '81']
# ['EROMUU' '52']
# ['SUFHUY' '3']
# ['NUFDOJ' '25']
# ['KUQCAB' '32']
# ['CIGJAD' '31']
# ['VATJIK' '95']
# ['PUWFET' '21']
# ['LUVYEI' '55']
# ['FAQWEB' '24']
# ['KUSJIR' '135']
# ['ZIBBET' '9']
# ['CONXIN' '41']
# ['MAFXAT' '88']
# ['NAPHET' '43']
# ['WOSGIU' '27']
# ['RAQROR' '51']
# ['XUDTIB' '111']
# ['ZZZJII01' '17']
# ['KUQVOI' '35']
# ['DIQCIR' '79']
# ['BEMCAZ' '76']
# ['QOPKUB' '57']
# ['QAGDEK' '23']
# ['QEKXUZ' '37']
# ['CEDHUQ' '26']
# ['QETKOP' '119']
# ['PUVPED' '6']
# ['GEJBUU' '37']
# ['TESDOL01' '22']
# ['SUPFOY' '58']
# ['KOWTEV' '77']
# ['GUWPIZ' '87']
# ['AMIXPO' '69']
# ['MUXGOD' '7']
# ['YEPXAS' '45']
# ['UKIJUV' '151']
# ['NADYUM' '106']
# ['XATZAT' '12']
# ['MNHCHA' '75']
# ['RAFWAX' '7']
# ['FOMTAE' '64']
# ['EFOTEY' '10']
# ['XOJHOU' '20']
# ['GLYCIN35' '16']
# ['BICMAD' '24']
# ['XAVZUP' '37']
# ['FIGMAJ' '66']
# ['BUYRUI02' '73']
# ['MOLMUV' '31']
# ['PATXAJ' '140']
# ['COXZAS04' '12']
# ['PHALIM' '49']
# ['MSORAM10' '61']
# ['XAVZUP' '29']
# ['HIWNAE' '31']
# ['VEVVOJ' '26']
# ['AZALIX' '30']
# ['WAKROS' '45']
# ['TABRET' '61']
# ['PESGOJ' '121']
# ['COTPAC' '50']
# ['EROFEX' '27']
# ['TAHHOC' '49']
# ['OTUDIR01' '68']
# ['DOJHOA' '83']
# ['VICREE' '27']
# ['XIXTUU' '67']
# ['EXUJAI' '12']
# ['BOQCUF01' '18']
# ['CILWUP11' '15']
# ['QEHSEB' '22']
# ['AZOTEP' '69']
# ['VUKZIL01' '61']
# ['NOKYER' '90']
# ['DAPJUA' '100']
# ['ISEBUD' '64']
# ['BEXGAM' '60']
# ['TIPVIZ' '55']
# ['WACJIT' '51']
# ['FACQAE' '5']
# ['QAKFAK' '8']
# ['UPAWEP' '79']
# ['DUHYIP' '113']
# ['UMOBAB' '177']
# ['KONHIE' '68']
# ['USUWOW' '65']
# ['LUYJIZ' '64']
# ['HIVLAA' '45']
# ['LONMEH' '32']
# ['FEZHAV' '78']
# ['EPANUF' '82']
# ['MNPYDO29' '10']
# ['DUBRAT' '90']
# ['GELWOL' '52']
# ['WEPWAQ' '61']
# ['CEKTOB' '71']
# ['OCEBAA' '100']
# ['ANPRAL' '113']
# ['URNFRO' '73']
# ['SOQNUI' '19']
# ['GOMJUO' '131']
# ['HABTEJ' '24']
# ['DIALAC02' '30']
# ['OKUXUP' '59']
# ['AXUDED03' '125']
# ['YECGIZ' '25']
# ['HEVLUP' '32']
# ['LAQSIG' '25']
# ['AZALIX' '10']
# ['TIMBAU' '16']
# ['NEYKIN' '9']
# ['SUCROS27' '60']
# ['HISTPU' '76']
# ['QOLVAP' '70']
# ['LIJJIY' '11']
# ['NADMUA' '189']
# ['ZAXLIV' '26']
# ['FEWMAX' '79']
# ['UJOSER01' '98']
# ['QOXPEZ' '31']
# ['KIJNUM' '102']
# ['EKUJUR' '10']
# ['ZEWDOU' '24']
# ['PYRCOX01' '56']
# ['PAPHOD' '72']
# ['DOKQIE' '48']
# ['ZZZVZC01' '95']
# ['XIXTUU' '63']
# ['XIHLIL' '70']
# ['LICLEP01' '76']
# ['MEMWUW' '168']
# ['CIRXAD' '77']
# ['LSERIN21' '34']
# ['WULYIN' '142']
# ['PUNLOB' '16']
# ['CABCUD15' '50']
# ['QALWOR' '46']
# ['HORZAQ' '17']
# ['PYRZAL10' '23']
# ['WEPWAQ' '59']
# ['ZIZRAD' '70']
# ['UTALIM' '92']
# ['NOCNEA' '114']
# ['JOPNAD' '102']
# ['UNUSED' '106']
# ['LUVPEY' '80']
# ['URAWER' '70']
# ['FOMTAE' '39']
# ['TALTIK' '35']
# ['CITVIL' '4']
# ['HORZAQ' '19']
# ['DUPDAU' '64']
# ['NUYJEW' '9']
# ['HOQGEB' '22']
# ['JEWCUK' '83']
# ['TESDOL01' '38']
# ['EMOGUJ' '55']
# ['PAJNIX' '107']
# ['PEPYIS' '99']
# ['ZEDFIZ' '55']
# ['XENQUD' '19']
# ['KUQCAB' '20']
# ['YATGIL' '64']
# ['DAJVUG01' '138']
# ['POVKIW' '58']
# ['VUQZOX' '53']
# ['GACSUB' '39']
# ['PAMPAX' '57']
# ['TRIRED' '27']
# ['DIPMUK' '6']
# ['MOZWII' '71']
# ['GIVXUE' '53']
# ['QONVIZ' '117']
# ['XOMWAX' '70']
# ['QAMSII' '158']
# ['JOCKOC' '105']
# ['DAPJUA' '136']
# ['DUTTAN10' '29']
# ['FUZYUU' '48']
# ['IBOLUG' '40']
# ['GIZSOX' '122']
# ['CECWAK' '25']
# ['XEDDAM' '51']
# ['INEZUY' '27']
# ['PYRIDS03' '40']
# ['BEMCAZ' '65']
# ['HYZMAC' '10']
# ['TALTIK' '172']
# ['SEQVAN' '33']
# ['TATYAQ' '135']
# ['DIDXOE' '54']
# ['FOWDAY' '78']
# ['DASRIY' '44']
# ['ISPADN' '60']
# ['ZERJIR' '36']
# ['CAZDIS' '110']
# ['REGYEH' '51']
# ['LIWJOQ' '59']
# ['TIQROC' '135']
# ['LCYSTN25' '42']
# ['NUMXAV' '16']
# ['APENOA' '51']
# ['LUYJIZ' '69']
# ['HXOXAM10' '56']
# ['JASLEV' '32']
# ['HTDZDX10' '54']
# ['DTBIUR' '11']
# ['PYRZAL10' '18']
# ['BUTGAA' '23']
# ['FOWDAY' '97']
# ['DAZDOZ' '185']
# ['QALWOR' '4']
# ['PAZDID' '58']
# ['GEMLUH' '24']
# ['FOGHOY' '27']
# ['FICYUM' '17']
# ['MOHCUI' '86']
# ['KEPFOC' '114']
# ['MODYOU' '13']
# ['UREAXX27' '30']
# ['RIDKIZ' '22']
# ['XAJSAE' '53']
# ['INOSND10' '23']
# ['QIPFIG' '43']
# ['FADCUI' '48']
# ['XAVMAJ' '96']
# ['MCPRAC01' '21']
# ['KEQQED' '16']
# ['SOVNEX' '135']
# ['DMANAP02' '133']
# ['AGEQIO' '70']
# ['USUWOW' '57']
# ['APENOA' '62']
# ['LINKAW' '163']
# ['WAFLEW' '26']
# ['XYLTOL02' '59']
# ['KAFLEI' '157']
# ['ZESSOF' '54']
# ['TEDROL' '21']
# ['KULMUA' '36']
# ['KIHZUY' '79']
# ['LCYSTN25' '45']
# ['EXIGOI' '150']
# ['GUNSIS' '49']
# ['TARBUL' '57']
# ['GEDYAQ' '41']
# ['YARZUN03' '47']
# ['JAKKIP' '49']
# ['FUHTAE' '80']
# ['DAMDAZ' '70']
# ['JUBCEO' '64']
# ['YAGQOM' '52']
# ['GIKTUP' '62']
# ['SEQBUN' '63']
# ['HOLQUU' '34']
# ['CASCIJ01' '66']
# ['HARJIV01' '56']
# ['YANSEN' '56']
# ['SEPNUX' '23']
# ['HMTOFA07' '106']
# ['ITIPEG' '58']
# ['FADYIV01' '21']
# ['QUVFIX' '45']
# ['ROGDIB' '78']
# ['BECYAL' '142']
# ['IMEZIL' '26']
# ['LUMJOU' '7']
# ['FEDCUO' '86']
# ['EDAJIE' '18']
# ['MAPZAF' '43']
# ['AMSALA02' '9']
# ['ZOYCOH' '69']
# ['DIQCAJ' '42']
# ['UWOSAC' '58']
# ['HEMLAM' '14']
# ['OXOFMB' '41']
# ['NADREN' '73']
# ['EKUKEC' '73']
# ['GLYCIN35' '19']
# ['LONRAI' '66']
# ['ZEXYOQ' '64']
# ['VIZCEO' '24']
# ['YITBOS' '61']
# ['BICMAD' '17']
# ['MALNAC02' '14']
# ['MUYTAC' '13']
# ['WADCUA' '44']
# ['NEZNEL' '49']
# ['COHLUI' '72']
# ['CINMER04' '65']
# ['FAHYOC' '53']
# ['XODDUQ' '166']
# ['XAJSUX' '11']
# ['FOMTAE' '24']
# ['QEYFUW' '45']
# ['XAYYUS' '62']
# ['MEOXAL' '29']
# ['GUCDEO' '47']
# ['XESRIW' '53']
# ['RAQROR' '27']
# ['ZAPGII' '109']
# ['XESRIW' '104']
# ['ZEFPUX01' '14']
# ['NPYRAM' '50']
# ['BUFCEM' '104']
# ['MIRTOW' '88']
# ['THYGLY10' '35']
# ['WOJPUI' '29']
# ['COKBAF' '39']
# ['OTUCOW' '38']
# ['UFEPAX' '99']
# ['IFIZIG09' '40']
# ['ZZZDUI02' '10']
# ['PEVKUX' '55']
# ['KUDZAL' '75']
# ['BUYRUI02' '52']
# ['GACSUB' '41']
# ['NIBZAM' '71']
# ['HATWII' '107']
# ['DOXHPX' '82']
# ['UQAFAV' '6']
# ['ACXMPR' '55']
# ['FOWQOY' '34']
# ['GAGVAL01' '120']
# ['YODHUV' '19']
# ['GAQSEY' '37']
# ['GUDKAS' '81']
# ['JUXHUF' '46']
# ['KAVYIP' '104']
# ['PIZGUA' '163']
# ['KEXNIK' '108']
# ['DUHJIB' '21']
# ['SAFKAL' '38']
# ['OQOSOD' '148']
# ['LENYUZ' '4']
# ['PUHHOQ' '68']
# ['NEHQAU' '12']
# ['AJAPIL06' '133']
# ['UJULIU' '31']
# ['FEZHAV' '16']
# ['XARQAK' '73']
# ['WAJQAC' '81']
# ['NIBZAM' '73']
# ['RATMEF01' '17']
# ['NINDOD' '99']
# ['NTRTAC01' '53']
# ['UHUMEP01' '29']
# ['UQISOE' '44']
# ['QIZZUW' '44']
# ['ADOJEK' '73']
# ['PELJOG' '25']
# ['FECVEP' '90']
# ['PORXEA' '36']
# ['VUYWUH' '43']
# ['DICHEC' '64']
# ['HODKAN' '130']
# ['YIGJOP' '29']
# ['WARCEZ' '27']
# ['GLUTAM08' '65']
# ['BALNIN04' '33']
# ['JEMJUG' '102']
# ['RIZFAI' '56']
# ['KUQVOI' '5']
# ['DUJHEV' '57']
# ['IKABIG' '42']
# ['WEPTUH' '61']
# ['LORQUF' '150']
# ['QAJQAV' '5']
# ['XUMYEL' '63']
# ['FIPZIN01' '50']
# ['INACOQ' '115']
# ['NINDOD' '87']
# ['SOZHUM' '26']
# ['ECIBIB' '127']
# ['HIYDEA' '30']
# ['IMIWOQ' '57']
# ['NUHLIN' '133']
# ['VEXREV' '59']
# ['ZIXPAZ' '2']
# ['DIFPEO' '113']
# ['YIHHON09' '41']
# ['GIRKOI' '35']
# ['CASYIG' '22']
# ['LEGLEQ' '138']
# ['ZIBBAP' '115']
# ['EJIQEU02' '33']
# ['HUKGOJ' '29']
# ['EDAJIE' '51']
# ['SUCROS27' '88']
# ['PAZFUS' '43']
# ['LUKCIF' '53']
# ['WOCQEK' '43']
# ['LSERIN21' '20']
# ['UVALIN01' '54']
# ['IMEZIL' '4']
# ['ULANUS' '25']
# ['GOMXIR' '166']
# ['OMEQUS' '48']
# ['VIPKIO03' '17']
# ['FOWDAY' '57']
# ['CIZSEL' '31']
# ['XOKVIE' '165']
# ['XEZBAG' '85']
# ['AROMAV' '119']
# ['TCHYZS' '44']
# ['WUFVAW' '57']
# ['TOLCAY02' '4']
# ['BIMSAR' '130']
# ['BEMCAZ' '72']
# ['TUJKIT' '83']
# ['GUZYEF' '96']
# ['CISPOJ' '46']
# ['WAKSUX' '37']
# ['MECPYZ' '87']
# ['YUZTET' '93']
# ['DOKQIE' '16']
# ['OBUSIN' '54']
# ['QIGVAD' '122']
# ['PEBCOO' '151']
# ['MOWBUX' '21']
# ['TAPBAP' '39']
# ['JIXGUS' '53']
# ['MEVDAT' '123']
# ['HETAUR20' '141']
# ['ADOFEF' '70']
# ['SARCEU' '113']
# ['TAFKUG' '55']
# ['COTTAI' '9']
# ['YODHIJ01' '77']
# ['VASTEQ' '14']
# ['QAGQAT' '61']
# ['ZUTKAC' '55']
# ['FAYJAR' '162']
# ['LIKLAU' '45']
# ['IHURUA' '2']
# ['LONJAA' '33']
# ['IMAZOL19' '13']
# ['ESOYUI' '39']
# ['OTUCOW' '35']
# ['GLYCIN18' '19']
# ['OGEFAI' '61']
# ['YICMIG' '68']
# ['SAFYIK' '121']
# ['VEHXAH' '105']
# ['YEJYIV' '65']
# ['PUXDOB' '153']
# ['TUNMUL' '89']
# ['NAFZEC' '112']
# ['LCYSTN25' '35']
# ['LUYJIZ' '20']
# ['NIJPEB' '37']
# ['GAFRAJ' '45']
# ['VONWAX' '70']
# ['TCHYZS' '58']
# ['HYXBUR10' '40']
# ['OJOLAC' '9']
# ['QURYUZ01' '62']
# ['AYAHOY' '96']
# ['JUPPAL' '29']
# ['JEMRIC' '73']
# ['RIGJOG' '86']
# ['UGECOA' '36']
# ['AFUTDZ10' '22']
# ['HIYDEA' '10']
# ['HOQHAW' '10']
# ['NADQOZ' '18']
# ['EBUKOB' '83']
# ['SALOXM04' '67']
# ['AMACAM01' '40']
# ['TAHGUE' '54']
# ['GEJSET' '80']
# ['BEHBOG' '40']
# ['PAMGIW' '49']
# ['BEVLOD' '68']
# ['ZENMUA' '56']
# ['YEKGUS' '40']
# ['VEZCAE' '35']
# ['TARCOE' '125']
# ['MOQLUA' '8']
# ['ILABEE' '119']
# ['KUTHEN' '156']
# ['EXUQAP' '47']
# ['WOWFOD' '37']
# ['QEMHIA' '14']
# ['KABLUX' '22']
# ['QOQGOT' '55']
# ['RAWBAS06' '38']
# ['WEVVOJ01' '78']
# ['SIXXON' '38']
# ['OJIVOU01' '45']
# ['LSERIN21' '55']
# ['BOCZIE' '108']
# ['QOZFER' '51']
# ['WUFVAW' '60']
# ['WEJCEU' '74']
# ['GACSUB' '53']
# ['DALQOW' '43']
# ['CBOHAZ02' '45']
# ['KEKCEJ' '62']
# ['VAZCEG' '52']
# ['JASLEV' '47']
# ['DOMQUS' '73']
# ['CBCPIC' '64']
# ['RAMVUW' '37']
# ['WILCOJ' '21']
# ['TAPZAN' '20']
# ['ESOYUI' '12']
# ['ZUJDEP' '95']
# ['IMAZOL33' '42']
# ['GATCAG' '56']
# ['DOWQAJ' '115']
# ['TAHGUE' '56']
# ['NOJKED' '40']
# ['PUBLON' '38']
# ['ACOHAC' '36']
# ['XEHDAS' '6']
# ['ARAQUH' '65']
# ['RAYPOY' '51']
# ['YILPAM' '27']
# ['BOLLIY' '26']
# ['CBOHAZ04' '17']
# ['ZERRET' '28']
# ['BOLLIY' '6']
# ['YIRDAG' '8']
# ['BOKSIE' '11']
# ['HIVGAW' '80']
# ['ODEZEE' '41']
# ['DEDWER' '25']
# ['FOLXIN' '55']
# ['DODNUF' '68']
# ['FOWQOY' '23']
# ['DHPROX' '56']
# ['DOJHOA' '88']
# ['FEXBUF' '47']
# ['AYAWIH' '83']
# ['BAGQIJ' '48']
# ['SAFYIK' '158']
# ['MINCIW' '69']
# ['TUJKIT' '86']
# ['SOVZAE' '112']
# ['WAZDEG' '94']
# ['FIBGAA' '76']
# ['OHUSIV' '86']
# ['DTBIUR' '19']
# ['IFIZIG09' '43']
# ['YOTYOW' '35']
# ['IZARAC' '11']
# ['SOVNEX' '23']
# ['SATRIO' '98']
# ['ACERUX' '44']
# ['XEXYII' '87']
# ['IQOMIM13' '88']
# ['BIGUAN' '39']
# ['EDEBUK' '51']
# ['CUZJOY' '5']
# ['TUGJUB' '116']
# ['UNUSED' '89']
# ['ULEWIR' '19']
# ['UTUSUZ' '52']
# ['DNCOOC' '75']
# ['LETGIA10' '18']
# ['DUHYIP' '77']
# ['ACOGAA' '62']
# ['DTUREA10' '26']
# ['FUTDED' '45']
# ['CILBII' '108']
# ['UJIBAR' '28']
# ['DUKWUB' '30']
# ['GOCJIS' '78']
# ['LAYSOV' '76']
# ['OHUSIV' '15']
# ['EXIMAA' '52']
# ['XIHLIL' '66']
# ['CAZCIR' '77']
# ['TAFKAM' '56']
# ['COHLUI' '78']
# ['TIMWAN' '7']
# ['EROFEX' '31']
# ['LCYSTN25' '38']
# ['BUDPIB' '84']
# ['CAZBAI' '66']
# ['MEADEN05' '62']
# ['QEYCOM' '33']
# ['DOGPAQ' '28']
# ['HEXTIN02' '53']
# ['VOYPAA' '71']
# ['TABRET' '74']
# ['EWAJET' '14']
# ['QOXPEZ' '18']
# ['RAPGAR' '84']
# ['NEFLOA' '33']
# ['TOYLUO' '46']
# ['DUSHAB' '125']
# ['QQQFCY01' '141']
# ['XIXQUR' '15']
# ['KIHZUY' '74']
# ['LUVYEI' '103']
# ['QAFFOS' '123']
# ['ZDGLPN' '161']
# ['DAHPIL' '147']
# ['SOLHAD' '61']
# ['MEVDAT' '1']
# ['KOHMOJ' '34']
# ['METHOL04' '6']
# ['DMSCPY' '105']
# ['TAFKIU' '54']
# ['EDOREW' '10']
# ['HMBQOX10' '29']
# ['CUFFUG' '46']
# ['VAGTED' '46']
# ['JIQZOY01' '10']
# ['VIZWEI' '135']
# ['ITIXUE01' '11']
# ['INAFIN' '14']
# ['PYRZAL10' '17']
# ['CUFFUG' '66']
# ['ZEXYOQ' '29']
# ['LANXON' '51']
# ['XOCJEE' '19']
# ['WAPPUY' '91']
# ['OROMIT' '5']
# ['MOHCUI' '73']
# ['AJEGUS' '35']
# ['UMERAF' '53']
# ['QARZIV' '91']
# ['HABMED' '51']
# ['GITNUT' '72']
# ['HEQWOR' '22']
# ['GEJCAB' '72']
# ['KEBGAB02' '85']
# ['FUQSAN' '12']
# ['NOKYER' '120']
# ['ZZZVZC01' '10']
# ['PEMQUT' '110']
# ['BUHYEI' '60']
# ['BELBUP02' '5']
# ['KUGZER' '70']
# ['OJUMOX' '133']
# ['AGUSEB' '59']
# ['LIWGUU' '54']
# ['ALATIN02' '55']
# ['LIJXOR' '49']
# ['LAKRAR' '43']
# ['BAZYAC01' '63']
# ['GINMOG' '137']
# ['ANPRAL' '109']
# ['NUMXAV' '24']
# ['OWEKEH' '51']
# ['SEKPED' '56']
# ['LAKRAR' '51']
# ['UKIHUS' '23']
# ['OMIZOB' '11']
# ['CAKREM' '14']
# ['QEDFOW' '35']
# ['AHUZUZ' '44']
# ['BOQCUF01' '37']
# ['FADSAF' '9']
# ['TARCOE' '135']
# ['TIJKEC' '24']
# ['FOPDUL' '81']
# ['BONGIW' '52']
# ['TOLDAM01' '46']
# ['VUHDEJ' '33']
# ['FOYGIL' '25']
# ['KAMRAS' '44']
# ['SETFUS' '129']
# ['MOQLUA' '50']
# ['AMSALA02' '1']
# ['SOJGED01' '47']
# ['SALOXM09' '50']
# ['AFASOQ' '63']
# ['ATZCBX' '25']
# ['SUSYAI' '71']
# ['IBPRAC14' '131']
# ['WAGMOH01' '122']
# ['SUCROS27' '21']
# ['OCPNDN' '98']
# ['OBUSIN' '142']
# ['ELEYOJ' '63']
# ['PYRDMD' '50']
# ['OKUXUP' '71']
# ['FEXLEZ' '90']
# ['ZIWXEK' '41']
# ['UQALUU' '84']
# ['UQAFAV' '46']
# ['VOHXIB' '71']
# ['TIMCHX' '60']
# ['GEPRUQ' '24']
# ['QAHPIZ' '90']
# ['APMCOX' '29']
# ['GEHBAX01' '56']
# ['PAZCUO' '15']
# ['XIBTEJ' '25']
# ['ESOZAP' '80']
# ['QIKZAN02' '148']
# ['GEXGIZ01' '19']
# ['MEVDAT' '164']
# ['CEKVIX' '37']
# ['UGECOA' '33']
# ['ABUBEE' '19']
# ['VIPSAP' '88']
# ['TEYPIW01' '85']
# ['LUVYEI' '175']
# ['XYLTOL02' '73']
# ['ODIKES' '55']
# ['KENMOF' '105']
# ['LCYSTN25' '49']
# ['CAXNIY' '70']
# ['AJAJEA' '2']
# ['ALUQIH' '82']
# ['MAYGEZ' '116']
# ['KODXEI' '46']
# ['DMTRZT' '34']
# ['PIWDUU' '152']
# ['YEKJEF' '31']
# ['DMETSO06' '18']
# ['EXIGOI' '144']
# ['WAKNUS' '78']
# ['NIPLED' '4']
# ['FAFKEC' '153']
# ['QOGPOR' '88']
# ['SOLLOV02' '14']
# ['RIZZEH' '60']
# ['OVIFUV' '74']
# ['ACOWIY' '76']
# ['WAKROS' '21']
# ['GULHAW' '45']
# ['JUTGEK' '144']
# ['BISMEV10' '32']
# ['PAMQAW' '29']
# ['AZOTEP' '29']
# ['HEPHUF' '20']
# ['WAKSUX' '125']
# ['PUKFAD' '114']
# ['MOXCIL' '80']
# ['CEPNAN' '9']
# ['NUYMUQ' '24']
# ['ANITOI' '66']
# ['YEXNEU01' '17']
# ['GLUTAM08' '54']
# ['XOJQUK' '59']
# ['XUYZIC' '21']
# ['BUKVAE' '49']
# ['UVALIN01' '74']
# ['BOKSIE' '28']
# ['VAWMAJ' '97']
# ['SAQZAK' '43']
# ['GIZBUN' '30']
# ['DONTAB' '58']
# ['FOWDAY' '68']
# ['ITIWIT' '2']
# ['OXTTCD' '35']
# ['ZEFPUX01' '5']
# ['SORBPY20' '39']
# ['DOWQAJ' '103']
# ['UJIBAR' '17']
# ['IPUCUT' '100']
# ['QOLVAP' '4']
# ['PHGLYA' '23']
# ['XIHLIL' '23']
# ['XEHDAS' '18']
# ['XAQNOT' '46']
# ['OXAZDO' '61']
# ['ZEJJED' '5']
# ['TALTIK' '170']
# ['OREHOK' '68']
# ['XUDSEW' '3']
# ['WAXNUH' '75']
# ['HODMOD' '81']
# ['TESKUZ' '4']
# ['QIZZUW' '26']
# ['GEJSET' '84']
# ['ANGULF' '82']
# ['XAZDUY' '16']
# ['WEPWAQ' '55']
# ['ZZZGWW02' '80']
# ['BIZTOV' '56']
# ['ECUXOQ' '133']
# ['VOZHUN' '67']
# ['HEWKAW' '93']
# ['KUQQEU' '157']
# ['CAKZAP' '46']
# ['GIZBUN' '26']
# ['JOWWIB' '78']
# ['LOSLAI' '33']
# ['DZHPDO' '61']
# ['SADBEE' '140']
# ['TEOXDE01' '8']
# ['ACERUX' '2']
# ['VUBZUN' '47']
# ['UVIZEG' '3']
# ['HUKRUA' '78']
# ['DAHFOI' '109']
# ['YOTYOW' '87']
# ['QAMSUU' '144']
# ['EBIROX' '155']
# ['VIDLIE' '59']
# ['CABCUD15' '49']
# ['CEWGUH' '50']
# ['WAJPUV' '90']
# ['CABCUD15' '83']
# ['KOHPUT' '63']
# ['TUHCEF' '105']
# ['INIJEW' '35']
# ['TBFRAC01' '11']
# ['MFZCHZ' '39']
# ['HIVLAA' '46']
# ['HOQGEB' '65']
# ['JABCEX' '70']
# ['ZZZJII01' '81']
# ['EBUKOB' '67']
# ['CITSED10' '31']
# ['REWYEX' '142']
# ['YEKJEF' '17']
# ['CEWGUH' '26']
# ['NEYMOT' '143']
# ['DOLTAZ' '62']
# ['ILOFIA' '71']
# ['BEVXEF01' '83']
# ['CUPYUJ' '53']
# ['QANRUT01' '27']
# ['FORAMO' '13']
# ['YEFDOE' '84']
# ['JENHEP' '43']
# ['JEVPOQ' '16']
# ['FEHDAX01' '72']
# ['BALNIN04' '20']
# ['SIYBEJ' '62']
# ['BEHBOG' '108']
# ['KAHJEI' '90']
# ['LIKKUN' '56']
# ['XOKVIE' '67']
# ['PABHAB' '126']
# ['PECZOO' '41']
# ['THCHYD' '4']
# ['UJOSER01' '94']
# ['TANTAD' '87']
# ['YIHHON09' '45']
# ['IQOMIM13' '96']
# ['KOJSUZ01' '76']
# ['ZAPGII' '118']
# ['AGEVOZ' '50']
# ['QQQFCY01' '198']
# ['RIYQOG' '54']
# ['MUQBUV' '48']
# ['ZZZNWQ01' '97']
# ['IFIDUW' '97']
# ['XIWBAI' '38']
# ['ELIGOX' '45']
# ['PUBLON' '5']
# ['DSCARA' '17']
# ['CIWNED' '74']
# ['WAFGER' '6']
# ['IQUJEK' '47']
# ['CAFVUA' '56']
# ['DAPXEX' '65']
# ['MOPSER' '160']
# ['PUVPED' '63']
# ['TANCUI' '10']
# ['IVEZEO' '134']
# ['DODNUF' '44']
# ['TEHMUO' '77']
# ['YIKQOY' '47']
# ['UKIHON' '90']
# ['OXTTCD' '37']
# ['QIKZAN02' '172']
# ['MEVDAT' '140']
# ['BETBEH10' '73']
# ['IXAQAB' '41']
# ['DOZKOS' '120']
# ['UKIHON' '74']
# ['EFITAP' '66']
# ['WIGKIH' '80']
# ['IPAWAX' '14']
# ['OCETUN' '125']
# ['KEFZUR' '92']
# ['VUYWUH' '47']
# ['KOFKIZ' '77']
# ['YAWXEZ' '49']
# ['KEHYAZ' '63']
# ['ELEYOJ' '87']
# ['HINXAF' '26']
# ['TBPMTZ' '72']
# ['MOWBUX' '13']
# ['KICCOO11' '138']
# ['MADGAC' '10']
# ['JEVPOQ' '30']
# ['PAXTIT' '81']
# ['CIDROW' '93']
# ['LEMGEQ' '68']
# ['ILOFIA' '45']
# ['IFIYIF' '96']
# ['WUNCOZ' '59']
# ['JOHJIB01' '51']
# ['COFHOW' '72']
# ['BOCZIE' '49']
# ['LENBAH' '67']
# ['TOVTED' '43']
# ['OGEGIR' '52']
# ['ONIVOY' '64']
# ['LIWJOQ' '46']
# ['YOTSOR' '18']
# ['RAFWAX' '67']
# ['OCIBIL' '27']
# ['XIHKUU' '69']
# ['TIWHAK' '19']
# ['QAFFIM' '12']
# ['VEYVOK' '38']
# ['UREANT03' '49']
# ['DIVRIJ' '55']
# ['TOBRUX01' '54']
# ['DEFYUI' '92']
# ['UJOSER01' '30']
# ['ELEWUN' '24']
# ['PICNOE' '78']
# ['WIKGEC' '21']
# ['EFOTEY' '59']
# ['XUDQUJ' '48']
# ['APITIE' '54']
# ['XOSCAK' '86']
# ['ZEQVIC' '38']
# ['COXXUJ' '32']
# ['ADEZUF' '14']
# ['CEDHUQ' '51']
# ['PAJNIX' '75']
# ['BIZBET' '100']
# ['NESFIA' '48']
# ['JINYIP' '162']
# ['JAKKEL' '19']
# ['HIVLAA' '40']
# ['YUZTET' '68']
# ['ARADEN10' '58']
# ['BOLLIY' '10']
# ['MEGLAN01' '17']
# ['TALSOP' '44']
# ['UKIJUV' '163']
# ['FUQYIB' '23']
# ['ETBARB' '32']
# ['PAXTIT' '97']
# ['BEHBOG' '145']
# ['CUMBUH' '77']
# ['LOBHIV' '33']
# ['ECAGIA' '37']
# ['GATCAG' '67']
# ['DUZFUB' '4']
# ['SOJHEE' '68']
# ['DOWQAJ' '55']
# ['TRURET20' '97']
# ['NICOAM06' '42']
# ['HAHDOL' '86']
# ['TACGIN' '78']
# ['TOBRUX01' '67']
# ['DAXSAZ' '77']
# ['LSERIN21' '10']
# ['KEPKAR' '57']
# ['QENYOX' '56']
# ['GATCAG' '58']
# ['PUHHOQ' '72']
# ['MFZCHZ' '16']
# ['GIXFID' '151']
# ['SARCEU' '118']
# ['LEJKOA' '61']
# ['ENINIA' '136']
# ['YIDBAO' '17']
# ['KOFZOW' '28']
# ['EFOQOG' '96']
# ['PICAMD06' '15']
# ['OXUMAW' '170']
# ['HADFEY' '54']
# ['JAKKEL' '24']
# ['MOZSEZ' '52']
# ['ZESSOF' '140']
# ['XAYYUS' '44']
# ['QAKFAK' '82']
# ['CEVGIT' '99']
# ['UPANIJ' '27']
# ['QIYRIZ' '28']
# ['DEFYUI' '81']
# ['KOYLIT' '98']
# ['QODQEF' '140']
# ['DAHHUS' '66']
# ['LUZFUJ' '14']
# ['XUBZID' '35']
# ['ONIVOY' '81']
# ['BEHBIA' '130']
# ['MAFXAT' '100']
# ['LUQPOE01' '33']
# ['NINZIV' '7']
# ['CEKVIX' '29']
# ['OVAYAM' '157']
# ['UGUXAW' '180']
# ['HUKRUA' '14']
# ['FAFKEC' '89']
# ['VEHXAH' '141']
# ['HOJLIC' '37']
# ['OQOSOD' '143']
# ['BCBANN06' '8']
# ['TAZPYR' '52']
# ['IZUGOZ' '60']
# ['ZEGCAR' '122']
# ['BODFEF' '118']
# ['AKIKEM' '44']
# ['LIPWEM' '89']
# ['XEXVEB' '166']
# ['BEHZIX' '105']
# ['XADPEA' '24']
# ['CYSTAC08' '76']
# ['TABRET' '64']
# ['TAZOLD01' '71']
# ['TUJWOL' '72']
# ['LSERMH15' '36']
# ['VAZBUV' '38']
# ['THZTAZ' '31']
# ['DIPICA10' '53']
# ['NICGAH' '28']
# ['EVIQAB' '44']
# ['XOMBEH' '7']
# ['INEZUY' '51']
# ['XEXYII' '101']
# ['CUFFUG' '92']
# ['NUPTIC' '28']
# ['LODWOR' '28']
# ['DOHDEJ' '110']
# ['KOVHOS' '182']
# ['DOXKOR' '135']
# ['TECNUL' '34']
# ['HAMJEL' '57']
# ['PINGAW' '90']
# ['ZEWDOU' '20']
# ['QQQGEM01' '15']
# ['VOHCEC' '69']
# ['PIFZAG' '56']
# ['TUNYUY' '17']
# ['TAURIN04' '22']
# ['HAJXIB' '93']
# ['CBCPIC' '45']
# ['NAHMUE' '127']
# ['EBULAO' '40']
# ['BCBANN06' '93']
# ['TIBMUM' '162']
# ['QALWOR' '60']
# ['XISNET01' '84']
# ['ZUTKAC' '66']
# ['QUMWEB' '135']
# ['HYZMAC' '32']
# ['LIPSUA' '75']
# ['KEHYED' '152']
# ['SUYWOA' '110']
# ['XUDQUJ' '62']
# ['QONRUI' '142']
# ['GIQRAZ' '68']
# ['IBOLUG' '51']
# ['JUVMUI' '45']
# ['GOVKEH' '76']
# ['KIKVAC01' '102']
# ['GAZGOF' '27']
# ['MORPDS01' '53']
# ['ZUJDEP' '38']
# ['KACGIG' '40']
# ['IJEPOE' '17']
# ['XUHREX' '45']
# ['THZTAZ' '24']
# ['KOVGIL' '66']
# ['IBOLUG' '38']
# ['CYSTAC08' '41']
# ['KEPFUI' '53']
# ['YUZTET' '54']
# ['AMXBPM10' '54']
# ['YANSEN' '64']
# ['SOYRII' '15']
# ['RIWTIB01' '40']
# ['JESJIB' '131']
# ['HUGFUL' '27']
# ['BUWHUW' '118']
# ['ZAQJEI' '8']
# ['HOQGEB' '34']
# ['NEXSIU' '9']
# ['HOQHAW' '25']
# ['KOJSUZ01' '61']
# ['NOKYER' '96']
# ['VOSDIQ' '15']
# ['ATDZSA04' '69']
# ['ULANUS' '54']
# ['BIZBET' '17']
# ['XUHPIB' '69']
# ['DEHSAK10' '48']
# ['CIRXAD' '32']
# ['OJUMOX' '26']
# ['KEPFOC' '82']
# ['JIXCOI01' '74']
# ['LIWGUU' '15']
# ['QUVFIX' '20']
# ['EXUJAI' '109']
# ['DOGQUL' '41']
# ['KUZKOG' '149']
# ['RATMEF01' '26']
# ['VUHDEJ' '48']
# ['LINCIU' '78']
# ['XOJSAS' '130']
# ['EKATOB' '96']
# ['GUWPIZ' '78']
# ['FINWOO' '98']
# ['CAZDOY' '84']
# ['TIJKEC' '17']
# ['GEJCIJ' '28']
# ['JEJZAA' '25']
# ['FIZZOD' '33']
# ['YOJQUL01' '22']
# ['NOSLEM' '44']
# ['LIJXOR' '41']
# ['MOKPUX' '114']
# ['DOZNOV' '71']
# ['KUPCOP' '123']
# ['WAKNUS' '102']
# ['XIMQUG' '85']
# ['LAYYUH' '133']
# ['LETDUJ' '54']
# ['HURXOH' '71']
# ['BOQQUT08' '53']
# ['BABFUI' '60']
# ['QONRUI' '148']
# ['DOBPIV' '35']
# ['LEGLEQ' '153']
# ['JASLEV' '73']
# ['AGEQIO' '20']
# ['ITIWIT' '11']
# ['GOTSOX' '91']
# ['VEZNEV' '111']
# ['YOGJUB' '87']
# ['XAHLOJ' '24']
# ['QUCGEC' '75']
# ['SOYVEJ' '23']
# ['PUHJIM' '38']
# ['IMAZOL33' '27']
# ['COHLUI' '89']
# ['BOKSIE' '62']
# ['TUMZAE' '59']
# ['QALQIE' '22']
# ['YEKJEF' '33']
# ['DOMQUS' '23']
# ['POFKAY' '95']
# ['PROLON01' '48']
# ['MAYGEZ' '132']
# ['NOETNA02' '118']
# ['LUVYEI' '44']
# ['VAYJIO' '26']
# ['FADBOB' '119']
# ['TOAZCD' '33']
# ['MAPYNM' '40']
# ['XODBAU' '99']
# ['RUYSUZ' '9']
# ['PIPNFP' '160']
# ['VUWXIU' '119']
# ['QOZFER' '46']
# ['LANYAA' '47']
# ['COQQEE' '41']
# ['UREWAQ' '166']
# ['YUZTET' '24']
# ['CECWAK' '40']
# ['TIMFUS' '104']
# ['XIHLIL' '69']
# ['NUMRAP' '95']
# ['JUKWIV' '131']
# ['HXOXAM10' '83']
# ['AFASOQ' '10']
# ['CIGGAC' '33']
# ['FOPDUL' '123']
# ['LODWOR' '32']
# ['DOGQOF' '28']
# ['FOGWED' '93']
# ['PUTTUU' '66']
# ['FOWTER' '77']
# ['DAFWAI' '28']
# ['DOJHOA' '20']
# ['KAVYIP' '99']
# ['LUVYEI' '88']
# ['TAHHOC' '39']
# ['LAKRAR' '38']
# ['WAFGER' '82']
# ['JEMRIC' '16']
# ['EMUMOQ' '121']
# ['LILLEY' '61']
# ['SEKPED' '63']
# ['HUHWAI' '78']
# ['ZEXJAP' '44']
# ['LEWZIY' '35']
# ['BOQQUT08' '51']
# ['JIYWET' '38']
# ['RELLAV' '71']
# ['NULCII' '165']
# ['NINZIV' '33']
# ['YIFGAW01' '17']
# ['APMCOX' '33']
# ['XAZDUY' '96']
# ['KOJZUE' '167']
# ['ZUTKEG' '47']
# ['CONNID' '18']
# ['XAYYUS' '67']
# ['AMFORM' '3']
# ['ROGQIO' '8']
# ['EVIXEM' '100']
# ['NIGNOH' '94']
# ['WAHGUI' '43']
# ['RAHSEY' '117']
# ['DTCZME' '79']
# ['QIYRIZ' '33']
# ['DIQCIR' '52']
# ['PYZTAZ' '15']
# ['DAXSAZ' '56']
# ['HABTEJ' '28']
# ['NRURAM11' '57']
# ['BIDCEW' '51']
# ['NUQPOF' '17']
# ['XIVBEK' '87']
# ['QQQFGS10' '43']
# ['QONRUI' '99']
# ['QEKSOP' '92']
# ['TAQXAL' '26']
# ['QORROF' '90']
# ['CYSTAC08' '64']
# ['ODOHIA' '76']
# ['DOVDIC' '70']
# ['UPIKUB' '30']
# ['SIGBOZ' '48']
# ['BENZIE01' '142']
# ['PIKGIZ' '128']
# ['JAKKIP' '30']
# ['TIMBAU' '88']
# ['ZIKTIW' '65']
# ['QEKSOP' '133']
# ['ROFQIO' '150']
# ['FUVDOP' '93']
# ['VECXIL' '31']
# ['CIWNED' '80']
# ['DTBIUR' '23']
# ['VAVHEH' '85']
# ['HAMCEF' '64']
# ['PICNOE' '75']
# ['PEFGEO01' '92']
# ['YEKHIH' '56']
# ['PEJVOQ' '74']
# ['NUPTIC' '14']
# ['FADCUI' '66']
# ['NAYKOO' '100']
# ['WATDAW' '127']
# ['XEXVEB' '179']
# ['NICOAM06' '56']
# ['XUHPIB' '48']
# ['BOGGAH' '66']
# ['JURQAO' '36']
# ['GUZYEF' '27']
# ['AJODOU' '52']
# ['YUKVAB' '159']
# ['LOSLAI' '50']
# ['INIJEW' '76']
# ['BZDMAZ05' '27']
# ['INOSND10' '98']
# ['MUTVEE' '25']
# ['WEVVOJ01' '62']
# ['LIKDIS' '82']
# ['OJIVOU01' '39']
# ['THYMMH' '47']
# ['IMEZIL' '43']
# ['FADBOB' '122']
# ['ACOTHI' '53']
# ['IJARES' '33']
# ['FIGYID01' '59']
# ['BIXNEB10' '67']
# ['QIGVAD' '73']
# ['UREWAQ' '130']
# ['PUNMAO' '43']
# ['ZEWDOU' '18']
# ['DEHYUM' '80']
# ['AZALIX' '38']
# ['ATZCBX' '15']
# ['IQUJEK' '87']
# ['LIKKUN' '43']
# ['BATSUK' '63']
# ['FEHVIY' '53']
# ['AMIXPO' '82']
# ['KOXBOO' '72']
# ['JECVUI' '82']
# ['BZAMID06' '52']
# ['VEHCUG' '120']
# ['NIXPUF' '51']
# ['LUMKIP' '114']
# ['KUZRAZ' '98']
# ['CUPZIY' '88']
# ['TETZOL02' '6']
# ['DIMEDO03' '85']
# ['MTETAC01' '32']
# ['RIZZEH' '65']
# ['RAMGUH01' '21']
# ['FINTAZ03' '145']
# ['AJASAG' '83']
# ['LEZQUE' '77']
# ['YUQDEU' '47']
# ['CEDXUE01' '45']
# ['KUCPED' '63']
# ['IJEPOE' '12']
# ['LIDCAE01' '63']
# ['KEMHOB' '71']
# ['HYQUIN' '39']
# ['LUKNAG' '124']
# ['WURLAY' '170']
# ['DOCMEO' '114']
# ['GISKEA' '80']
# ['GEDYEU' '46']
# ['QALQIE' '90']
# ['INOSND10' '131']
# ['XAYROG' '75']
# ['GLUTAM08' '45']
# ['HTHSOC' '147']
# ['KASZEK' '62']
# ['SAWNAH' '19']
# ['XADBAI' '93']
# ['CEGXES' '33']
# ['QARVUB' '48']
# ['JESNAX' '90']
# ['LSERMH15' '61']
# ['CSURCD10' '63']
# ['JEJZAA' '38']
# ['NIGNOH' '20']
# ['VESJUZ' '107']
# ['FUTFIJ' '67']
# ['DELMOX' '55']
# ['KAHJEI' '77']
# ['GEJBUU' '41']
# ['VIZCEO' '17']
# ['UFORUE' '41']
# ['FOWDAY' '91']
# ['BEKBOI' '50']
# ['CITSED10' '61']
# ['FOZLIQ' '75']
# ['YARZUN03' '31']
# ['CYHEXO' '20']
# ['SIKJIF' '67']
# ['RAWBAS06' '31']
# ['NIBXOL' '95']
# ['BODFEF' '129']
# ['ZOGPAJ' '14']
# ['VATJIK' '108']
# ['FUYJIS' '35']
# ['YAXHUC' '21']
# ['CINSOH' '55']
# ['NESTIP' '26']
# ['GIRRUV' '46']
# ['UMOBAB' '95']
# ['TODSAG' '34']
# ['ATZCBX' '29']
# ['DIVRIJ' '89']
# ['KUZRAZ' '34']
# ['MUQBUV' '36']
# ['CEKBAX' '79']
# ['PIZGUA' '177']
# ['YILNOY' '33']
# ['AXASUO' '12']
# ['BOGRUL' '64']
# ['AZALIX' '52']
# ['DUBTEA' '74']
# ['QUCGEC' '3']
# ['PAPJUM' '49']
# ['SESQIR' '55']
# ['MOSKIP' '22']
# ['YATGIL' '129']
# ['AGUSEB' '65']
# ['TODSAG' '57']
# ['ACNPTH10' '111']
# ['XAYVIC' '29']
# ['VIKKEG' '19']
# ['BACXAE10' '91']
# ['OZAHEE' '69']
# ['NUMRAP' '64']
# ['GEJSET' '118']
# ['CIWWAI' '106']
# ['SERMUZ' '27']
# ['LONDOH' '16']
# ['TUHCEF' '160']
# ['ZIKMOV01' '61']
# ['HAJXIB' '124']
# ['ERIVAC' '41']
# ['SARBUI' '93']
# ['XEJYAN' '82']
# ['DIDFAY' '82']
# ['DAVYAA' '44']
# ['TEOXDE01' '10']
# ['QOHCIA' '22']
# ['ROFQIO' '46']
# ['GADPAE' '53']
# ['GEPRUQ' '80']
# ['EGAFAU' '137']
# ['NANQUO02' '68']
# ['OGEFAI' '81']
# ['LINKAW' '152']
# ['LEPMID' '89']
# ['COYNAF' '52']
# ['VAYLAI' '71']
# ['CAGJEC01' '37']
# ['ZUNTOR' '119']
# ['YIHLEI' '63']
# ['RATMEF01' '22']
# ['WARCEZ' '47']
# ['UGECOA' '46']
# ['NELQUQ' '118']
# ['XUDQUJ' '52']
# ['APITUQ' '36']
# ['QONRUI' '81']
# ['LENYUZ' '14']
# ['RIZZEH' '68']
# ['DAHDAR' '85']
# ['CAZDIS' '105']
# ['KIFJAK' '159']
# ['XUMYEL' '98']
# ['DUVFUV02' '117']
# ['PEBWOI' '146']
# ['QIHHIY' '140']
# ['QAHCUA' '90']
# ['FIZDIB' '35']
# ['ATOMAY' '61']
# ['HUYYAB01' '64']
# ['MEMWUW' '173']
# ['YAWXEZ' '63']
# ['FEMFUY01' '44']
# ['XOPWEF03' '19']
# ['RESKIK' '59']
# ['UVEGIN' '72']
# ['NICGEL' '54']
# ['ACERUX' '42']
# ['HEGFOP' '141']
# ['MOPSER' '95']
# ['MIOZPO01' '39']
# ['BEMCAZ' '75']
# ['SURSUT' '26']
# ['XUCJEM' '43']
# ['LAPSIG' '64']
# ['CABCUD15' '70']
# ['DUPDAU' '86']
# ['SUCROS27' '5']
# ['NUYJEW' '18']
# ['GUHROQ01' '99']
# ['FETNUO' '117']
# ['COJMUJ' '28']
# ['LUJMEK' '87']
# ['CEPNAN' '26']
# ['NEQWEN' '47']
# ['SAGRUN' '18']
# ['DEBMOM' '83']
# ['EWOVOB' '71']
# ['ZAWDIM' '31']
# ['ACICAR' '58']
# ['ACOGAA' '96']
# ['JIQZOY01' '24']
# ['MOSGEI' '107']
# ['VAYLAI' '60']
# ['SUYQEK' '32']
# ['MNPYDO29' '47']
# ['UXUYUJ' '4']
# ['QOQGOT' '53']
# ['PYRDMD' '42']
# ['ODOHIA' '3']
# ['NITPUB' '159']
# ['FINWOO' '95']
# ['TIMWAN' '11']
# ['KAWQEF' '14']
# ['KEDWEV' '124']
# ['FEJYIC' '49']
# ['NIGNOH' '128']
# ['GADPAE' '13']
# ['SALOXM09' '46']
# ['QALWOR' '24']
# ['BOQVIM01' '41']
# ['TESKUZ' '43']
# ['XIXTUU' '82']
# ['RUJNOA' '19']
# ['CIWVAH01' '7']
# ['BINROF' '102']
# ['PABHAB' '144']
# ['PECWEA' '19']
# ['ACACOX' '32']
# ['DIHRUH10' '75']
# ['JEMRIC' '33']
# ['CASCIJ01' '71']
# ['HNIMOZ' '61']
# ['JORBUN' '89']
# ['EXIGUO' '107']
# ['DIKXEB' '100']
# ['EXIVUD' '22']
# ['EXIGOI' '93']
# ['SUFHUY' '15']
# ['XEJYAN' '36']
# ['RIGJOG' '94']
# ['HETAUR20' '80']
# ['LIMKIB' '76']
# ['FEMFUY01' '56']
# ['DOGQAR' '38']
# ['HMUSCM' '21']
# ['EXIGAU' '137']
# ['PIFZAG' '84']
# ['WOCREL' '44']
# ['COWYAP' '85']
# ['IMEGIR09' '72']
# ['YOKJOZ' '20']
# ['QEMHIA' '32']
# ['XATZAT' '4']
# ['REHCAK' '76']
# ['MTZOPZ10' '86']
# ['ROZPUT' '4']
# ['EVIXEM' '108']
# ['ASODUJ' '53']
# ['NTPYRO12' '23']
# ['HEHQOC' '2']
# ['PEVKUX' '67']
# ['WOGFAZ' '97']
# ['QIKZAN02' '36']
# ['MACTUH' '67']
# ['PATXAJ' '26']
# ['WASRAJ02' '63']
# ['ADOJEK' '81']
# ['TAHHOC' '60']
# ['OGEFAI' '49']
# ['FOPDUL' '86']
# ['LUDFAR' '76']
# ['WARCEZ' '143']
# ['TEFMEW' '58']
# ['IKABIG' '40']
# ['QIQCUQ' '10']
# ['CUTTOB' '91']
# ['FUSJOT' '80']
# ['SOLHAD' '111']
# ['EMIJIT' '118']
# ['CDECOL11' '56']
# ['JORLOS01' '49']
# ['SURSUT' '10']
# ['EFUMAU03' '2']
# ['FEHVIY' '44']
# ['MISGAX' '42']
# ['PABNAK' '26']
# ['QUCGEC' '108']
# ['RAPRUW' '99']
# ['PUFJIJ' '25']
# ['QIFDOZ' '60']
# ['UWOSAC' '17']
# ['QINFUO' '40']
# ['CXHIMZ20' '81']
# ['QEHDEO' '65']
# ['BONGIW' '83']
# ['BABXUA' '10']
# ['JAKKIP' '67']
# ['EBUKOB' '6']
# ['WIFKEB01' '47']
# ['HAVKOE' '50']
# ['EMIMUI' '19']
# ['REVMIP' '53']
# ['QIJMUR' '169']
# ['GEJCIJ' '88']
# ['ZZZVZC01' '34']
# ['MOPSER' '91']
# ['WUXYAQ' '6']
# ['GACGAU' '137']
# ['FEHCUQ' '132']
# ['TAPBAP' '28']
# ['KOWYEA12' '13']
# ['IHAVEU' '135']
# ['WAZDEG' '115']
# ['VICREE' '32']
# ['HOFLAQ01' '83']
# ['SUCROS27' '39']
# ['XELNAE' '30']
# ['XUKDEN01' '45']
# ['IFIZIG09' '45']
# ['BUYZAW' '87']
# ['CEXQIG' '31']
# ['KABJUT' '50']
# ['ZAQHAC' '71']
# ['NSMACM' '48']
# ['CAHOAM' '29']
# ['FIGMAJ' '68']
# ['ZUJDEP' '68']
# ['ACIDOH' '36']
# ['GEJSET' '126']
# ['ONOHEF' '35']
# ['DOMDUE' '130']
# ['FEXLEZ' '146']
# ['GOCJIS' '90']
# ['HATWII' '149']
# ['OMAXOQ' '72']
# ['PUTTUU' '167']
# ['QIXXUS' '9']
# ['BUFMOG' '62']
# ['YELWES' '55']
# ['HAMJEL' '66']
# ['UHUMEP01' '15']
# ['HOYMAJ' '12']
# ['GULHEA' '78']
# ['CASCIJ01' '82']
# ['YEHPIK' '35']
# ['FAYBUC' '175']
# ['UPAWEP' '62']
# ['PAXQUC' '82']
# ['GLYCIN35' '12']
# ['PURINE01' '30']
# ['FIZDIB' '29']
# ['UFUXOI' '36']
# ['RIQWIZ' '150']
# ['BZDMAZ16' '15']
# ['GEJCAB' '66']
# ['ACOWOE' '10']
# ['DAHFOI' '100']
# ['QIRRUG' '33']
# ['GAUTAM15' '70']
# ['CAMGAA' '112']
# ['CUBRUN' '75']
# ['XEWNAP' '62']
# ['GLYGLY17' '66']
# ['EMUPAE' '106']
# ['HEWFEW' '84']
# ['VEZCAE' '83']
# ['VAVVET' '30']
# ['IQOMIM13' '73']
# ['PAPJUM' '33']
# ['OTUDIR01' '62']
# ['QODQEF' '100']
# ['RELLAV' '75']
# ['GAFRAJ' '36']
# ['HILVOO01' '9']
# ['TEDROL' '26']
# ['TILJUV' '59']
# ['BODFEF' '126']
# ['SAHPOI' '126']
# ['XAQNOT' '23']
# ['NUYJEW' '26']
# ['RASDUM' '108']
# ['KEFZUR' '52']
# ['PATTAF' '112']
# ['NIQVAL' '70']
# ['DAVARO' '73']
# ['ZZZJII01' '60']
# ['TEWHOS' '155']
# ['ACIDOH' '27']
# ['JOPNOR' '94']
# ['EHIXOI' '34']
# ['YASSIV' '58']
# ['TEVJIP01' '67']
# ['ABIRUZ' '106']
# ['ZZZJII01' '42']
# ['ZEGBIY' '91']
# ['CIGJAD' '33']
# ['LUDFOF' '101']
# ['NIXPUF' '60']
# ['XANHYD' '14']
# ['NIBZAM' '61']
# ['ITEGIX01' '31']
# ['VOBDOF' '77']
# ['RAFWAX' '44']
# ['KIBFEG' '37']
# ['NAPDCX' '34']
# ['UPOCEJ' '113']
# ['LIPWEM' '99']
# ['AGLYSL' '26']
# ['DIQCAJ' '3']
# ['UPOCEJ' '11']
# ['ONIVOY' '5']
# ['MUYBAK' '33']
# ['DZCDON' '29']
# ['BACRAA' '76']
# ['BISMEV10' '35']
# ['YOKJOY' '33']
# ['EFUMAU03' '8']
# ['BOMHOA' '84']
# ['KUZWUY' '36']
# ['XOJKAK' '58']
# ['DOWQAJ' '107']
# ['BCBANN06' '64']
# ['FOHFOY' '17']
# ['EXUJAI' '28']
# ['FUTFIJ' '28']
# ['DAVYAA' '42']
# ['XEFSIK' '113']
# ['EXETEI' '44']
# ['PORXUQ' '0']
# ['LSERMH15' '46']
# ['AXASUO' '39']
# ['KEQQED' '72']
# ['VAZBIJ' '64']
# ['KUQQEU' '35']
# ['ZZZRJG01' '32']
# ['CIRXAD' '27']
# ['JERHIX' '46']
# ['RIZHAK' '60']
# ['DEZBIV' '37']
# ['DOTRAG' '84']
# ['FOHFOY' '30']
# ['PUBLON' '51']
# ['ITIZUG' '44']
# ['JIXGUS' '50']
# ['JUVMIW01' '103']
# ['ODEZOO01' '66']
# ['DOBPIV' '44']
# ['TCMPCQ01' '114']
# ['EKUJUR' '35']
# ['KABMIL' '109']
# ['KOYLUH' '4']
# ['QIHHIY' '123']
# ['ESAREV' '64']
# ['DALGON03' '105']
# ['LASCAC12' '78']
# ['IMEGIR09' '93']
# ['JECCOJ' '119']
# ['NAXCIY01' '38']
# ['PEBTAU04' '96']
# ['PEMBEO' '55']
# ['COXZAS04' '110']
# ['ELIPAR' '171']
# ['XAHLOJ' '23']
# ['ZORJOF' '77']
# ['WAXNUH' '42']
# ['DAJXIV' '138']
# ['KAYTUZ' '92']
# ['TABDUY' '139']
# ['TRIRED' '20']
# ['WUHYIH' '73']
# ['BEHBOG' '21']
# ['BOQVIM01' '62']
# ['TEOXDE01' '6']
# ['LINJAT' '113']
# ['TABBEE' '9']
# ['HXIBAC' '30']
# ['JABCIB' '50']
# ['TUHHUZ' '125']
# ['QARVUB' '6']
# ['OHEPUO' '83']
# ['CISPOJ' '63']
# ['ZEDFIZ' '25']
# ['ATDZSA04' '67']
# ['HOMGOG' '116']
# ['KICCOO11' '102']
# ['FUNSOW' '31']
# ['XADBOW' '117']
# ['MODCUD' '42']
# ['CPCOHA' '44']
# ['DALGON03' '111']
# ['KORXAS' '56']
# ['HALMAK' '18']
# ['UPONAQ' '5']
# ['HINNEZ' '35']
# ['LEJKOA' '58']
# ['XOSJUK' '43']
# ['GINMOG' '150']
# ['ZDGLPN' '178']
# ['TURACD' '95']
# ['BOQQUT08' '78']
# ['MENMEY' '182']
# ['SATRIO' '157']
# ['PATTAF' '155']
# ['GAZPIG' '38']
# ['XULDUD01' '50']
# ['WOCVUF' '44']
# ['NABKIN' '81']
# ['LAKDAD' '78']
# ['VABLIT' '150']
# ['XULDUD01' '38']
# ['WAWWAU' '68']
# ['HILVOO01' '1']
# ['IZAWUB' '15']
# ['MAZMEH' '8']
# ['ACIDOH' '81']
# ['GOMXIR' '5']
# ['MOXCIL' '88']
# ['DODCHD' '88']
# ['BONGIW' '19']
# ['DICHEC' '53']
# ['TUJWOL' '19']
# ['SIGBOZ' '58']
# ['XEPNUD' '41']
# ['XISJIT' '25']
# ['HAMHUZ' '90']
# ['JUKWIV' '123']
# ['YILNOY' '61']
# ['LEKZEH' '105']
# ['VELNOR' '7']
# ['WARCEZ' '9']
# ['JIXGUS' '56']
# ['WIGBOE' '58']
# ['XEPNUD' '13']
# ['JEZZUJ' '86']
# ['ZAWDIM' '36']
# ['RASYOZ' '156']
# ['HEWFEW' '76']
# ['MESCZA' '16']
# ['NIGZEJ01' '4']
# ['HISTPU' '70']
# ['VIZZIP' '31']
# ['QIGCIS' '35']
# ['CAMGAA' '99']
# ['SUNJIU' '65']
# ['PIKGIZ' '90']
# ['BEPTUL' '55']
# ['ZOTDAP' '5']
# ['KEMZIL01' '19']
# ['ELIGOX' '48']
# ['BOVLEF' '107']
# ['TARCOE' '100']
# ['LONRAI' '87']
# ['HYZMAC' '15']
# ['QUSKOG' '38']
# ['REZMOY' '54']
# ['DEHYUM' '33']
# ['NUVXIM' '52']
# ['FENCIK' '56']
# ['BOQQUT08' '59']
# ['LIFNOE' '39']
# ['DOCMEO' '120']
# ['PATXAJ' '17']
# ['VEHXAH' '97']
# ['BIGUAN' '41']
# ['NEYMOT' '119']
# ['VEHXAH' '78']
# ['MNPYDO29' '54']
# ['IHANUB' '73']
# ['PEFLUI' '40']
# ['PORQAQ' '89']
# ['FACREG' '46']
# ['BASVOG' '30']
# ['ELULOM' '55']
# ['SAPDAQ' '94']
# ['IMICUE' '16']
# ['FOLVIL' '82']
# ['EXIGUO' '103']
# ['NABKIN' '88']
# ['NIJPEB' '32']
# ['DODCHD' '60']
# ['UKIKIK' '9']
# ['ZUTKAC' '62']
# ['CEBMUR' '56']
# ['YODHIJ01' '59']
# ['COKBAF' '28']
# ['UZOJIE' '57']
# ['EJISUN' '9']
# ['WIRYEB02' '18']
# ['GIRKOI' '29']
# ['KIHZUY' '62']
# ['FIYZAO' '182']
# ['TUHCEF' '113']
# ['ROGWOB' '36']
# ['IFIDUW' '116']
# ['CAXMOD' '34']
# ['FORMAM' '13']
# ['CARCAZ' '157']
# ['UTETOE' '147']
# ['LEGLEQ' '135']
# ['OGOKEC' '43']
# ['CIWMOL' '59']
# ['ACIDOH' '23']
# ['TAVXOF' '69']
# ['FUSVEW' '6']
# ['ADEZUF' '35']
# ['APMCOX' '23']
# ['IBUVUY' '53']
# ['TEVHEH' '93']
# ['SEQVAN' '7']
# ['VEFXOV' '113']
# ['GATCAG' '69']
# ['GUSVOH' '40']
# ['MUKLIO' '33']
# ['HIRRIK' '118']
# ['VAZZEB' '58']
# ['GUBARB10' '51']
# ['XIYXUZ' '7']
# ['LIFNOE' '36']
# ['YENDEC' '61']
# ['EVIJUP' '115']
# ['MAZGAX' '23']
# ['HOQGEB' '11']
# ['AJEGUS' '24']
# ['YANSEN' '49']
# ['LUJMEK' '111']
# ['IVALUO' '183']
# ['XEWNAP' '50']
# ['PATXAJ' '174']
# ['COKJOB' '83']
# ['RAZQOB' '85']
# ['MOWBUX' '17']
# ['REGYEH' '43']
# ['XANAZH01' '13']
# ['BUFCEM' '63']
# ['ISEDOB' '79']
# ['HAHDOL' '125']
# ['RAPRUW' '49']
# ['KEPDIU' '16']
# ['PECWAX' '18']
# ['OGIQOL' '14']
# ['LIPWEM' '71']
# ['XADPEA' '54']
# ['CABCUD15' '75']
# ['JOCKOC' '72']
# ['NUYMUQ' '38']
# ['MMCPUR' '38']
# ['NUYMUQ' '103']
# ['KAGMIO' '42']
# ['EVIJUP' '87']
# ['NOCNOK' '41']
# ['PUGTIV' '63']
# ['QIPVEQ' '78']
# ['SOWSEC' '29']
# ['QIQCUQ' '32']
# ['XAZDUY' '77']
# ['TAVXOF' '39']
# ['COHWIF01' '73']
# ['AGEVOZ' '8']
# ['LESPUW' '26']
# ['SEFZIM' '48']
# ['PUBMUU23' '54']
# ['DEZBIV' '38']
# ['FIBYEW' '59']
# ['WIFKOL' '51']
# ['WAWWAU' '120']
# ['HEYRIM' '112']
# ['QOQVOH05' '31']
# ['HESSIH' '50']
# ['VIGTUA' '65']
# ['OCETUN' '101']
# ['IMEGIR09' '46']
# ['KUSLIU' '62']
# ['MOBMEV' '56']
# ['HURXOH' '81']
# ['GIZYIY01' '14']
# ['DESJOA' '148']
# ['DOGQOF' '16']
# ['LUMKIP' '64']
# ['AVULIM' '49']
# ['HACMUT' '37']
# ['MEUREA01' '23']
# ['DOLSIG10' '96']
# ['XOCZUL' '75']
# ['NUYQEE' '54']
# ['YEXNEU01' '40']
# ['DOJPAT' '63']
# ['CUPYOD' '66']
# ['XESRIW' '100']
# ['KIBDOO' '53']
# ['YECVUX' '38']
# ['AXACEI01' '110']
# ['LESLAX' '66']
# ['QAMSUU' '83']
# ['AJASEK' '55']
# ['PODFIZ' '8']
# ['ATOXAL03' '29']
# ['LEPMID' '101']
# ['FINWOO' '89']
# ['NENXAF' '8']
# ['FOZLIQ' '38']
# ['ACYGLY12' '39']
# ['FEZHAV' '22']
# ['TACMSO' '16']
# ['HEQZEK' '31']
# ['PEDERL' '42']
# ['RONVEV' '47']
# ['ODEJEN' '95']
# ['PEBTAU04' '41']
# ['AZALIX' '42']
# ['DAYHIV' '38']
# ['ROGQIO' '186']
# ['VONWAX' '78']
# ['HMTOFA07' '78']
# ['RAHNOG' '51']
# ['HAWYIN' '46']
# ['HABFUL' '68']
# ['ROFQIO' '80']
# ['COXXUJ' '38']
# ['MOPPUC01' '34']
# ['LIXGOO' '63']
# ['FIZHAX' '83']
# ['KUZWUY' '140']
# ['GEWGUK' '107']
# ['YUHTIE' '51']
# ['GITNUT' '55']
# ['CBOHAZ02' '27']
# ['LOXBAD' '54']
# ['VAVHEH' '48']
# ['OTEBEV' '84']
# ['DACETA11' '28']
# ['DOZKOS' '76']
# ['DEZBOB' '46']
# ['YUQBAO' '27']
# ['LUMKIP' '102']
# ['XIDQIL' '13']
# ['GUDKAS' '123']
# ['WAXCUV' '70']
# ['VODWIU' '104']
# ['YEFXAJ' '57']
# ['PYRDMD' '69']
# ['TOLCAY02' '9']
# ['ZIYZEM' '95']
# ['ALLCAM' '109']
# ['ZEGCAR' '71']
# ['JEVPOQ' '11']
# ['XUMYEL' '67']
# ['LIPWEM' '81']
# ['QILZIU' '9']
# ['KUKHOP' '67']
# ['LONKIK' '60']
# ['NSBTOA' '60']
# ['PABHAB' '132']
# ['BIGFEC' '99']
# ['FENCIK' '65']
# ['TOCLUU' '50']
# ['HUHWAI' '36']
# ['QOWFUF' '195']
# ['PASZIS' '155']
# ['RATMEF01' '29']
# ['LUDFAR' '71']
# ['TATNBZ' '13']
# ['DOXKOR' '149']
# ['XARQAK' '99']
# ['BASVOG' '34']
# ['COHQEV' '108']
# ['LUJMEK' '102']
# ['THZTAZ' '47']
# ['ESOZAP' '13']
# ['BOMHOA' '56']
# ['LESLAX' '55']
# ['XUDTIB' '104']
# ['QAGQAT' '88']
# ['TEMDOG' '19']
# ['FUNXER' '49']
# ['BISMEV10' '20']
# ['LAJZAZ' '23']
# ['LANSOK' '72']
# ['MUYTAC' '49']
# ['LUDFAR' '19']
# ['VOFDEZ' '109']
# ['KASZEK' '69']
# ['OHUXEV' '6']
# ['DUVYEZ02' '58']
# ['XIVBEK' '33']
# ['VACROG' '155']
# ['ETDIAM17' '41']
# ['TEDFEP' '127']
# ['TUNYUY' '71']
# ['YILNOY' '67']
# ['ALUQIH' '110']
# ['XOJKAK' '56']
# ['WOCQEK' '29']
# ['VINXEW' '24']
# ['EGAFAU' '133']
# ['FIYZAO' '169']
# ['ALXANM01' '4']
# ['AJODOU' '45']
# ['FOWVIX' '101']
# ['TAYGUW' '5']
# ['ZIBBAP' '104']
# ['KAMFAH' '6']
# ['SOVNEX' '119']
# ['FEBBIZ' '79']
# ['KOKTEL' '67']
# ['FONMEB' '20']
# ['GLYCIN52' '26']
# ['GAUTAM15' '156']
# ['WOJPUI' '19']
# ['VEHCUG' '79']
# ['KODXEI' '33']
# ['DEKYIC' '187']
# ['KIHZUY' '67']
# ['HODKAN' '110']
# ['NADHOP01' '116']
# ['AHANOM' '88']
# ['UPIKUB' '50']
# ['GLYGLY17' '62']
# ['AJAJEA' '44']
# ['INEZUY' '48']
# ['MENPDL' '43']
# ['CICTEN' '143']
# ['AJASAG' '66']
# ['MOZSEZ' '4']
# ['DIRMIA' '21']
# ['PYRZIN14' '50']
# ['MAYXEP' '65']
# ['DUHTUW' '141']
# ['ICAKEC' '25']
# ['XABFOY' '48']
# ['SAGMOE' '37']
# ['SIGGUL' '69']
# ['FORRUB' '97']
# ['ACOWIY' '6']
# ['LIWJOQ' '49']
# ['VIGLAA' '63']
# ['AKEZIB05' '7']
# ['DTUREA10' '63']
# ['SODBIW' '56']
# ['NIFDAI' '109']
# ['QIJDES' '14']
# ['LIPVUB02' '59']
# ['PEBCOO' '161']
# ['OGIQEB' '27']
# ['NUTMOE' '7']
# ['DEMQIW01' '32']
# ['HUFFEU' '80']
# ['COKJER' '166']
# ['KOVHOS' '171']
# ['LUHSIR' '4']
# ['EXIMAA' '14']
# ['GADCIX' '153']
# ['DOXKOR' '130']
# ['GLICAC01' '21']
# ['BUFMOG' '30']
# ['DUDNAR' '47']
# ['ZODWIY' '93']
# ['HIZTEQ' '44']
# ['CAZDIS' '125']
# ['HAMHUZ' '103']
# ['HOJLIC' '27']
# ['FOWDAY' '106']
# ['LEJKOA' '48']
# ['TAHGUE' '81']
# ['FIFBAY' '114']
# ['GAUTAM15' '51']
# ['ZTNONX' '44']
# ['SAPXEM' '47']
# ['LITRAH' '91']
# ['BOQWUZ' '50']
# ['RAYPOY' '18']
# ['IQOMIM13' '68']
# ['RAHNOG' '73']
# ['GLUTAM08' '50']
# ['XUHREX' '59']
# ['HEVLUP' '29']
# ['FOYGIL' '19']
# ['CAZDIS' '117']
# ['DIPGIS11' '146']
# ['CIKWOJ' '20']
# ['LENBAH' '90']
# ['OSOLEO' '133']
# ...
# ['CUZJOY' '45']
# ['LONDOH' '12']
# ['UHAMOF' '22']
# ['NAXTIQ' '70']
# ['GLYCIN35' '10']
# ['IFIYIF' '74']
# ['TAZWIB' '18']
# ['WALDES' '125']
# ['ANOTAZ' '10']
# ['DAFPUV' '39']
# ['TAFKIU' '65']
# ['SIKGIC' '141']
# ['HISYEO' '4']
# ['ROBYAI' '126']
# ['SIGFEU' '123']
# ['TEZCOR' '57']
# ['QIPPUA' '131']
# ['OMEVIL' '61']
# ['YUFKUF' '37']
# ['WOLVUP' '56']
# ['VIKYOF' '46']
# ['QOHCIA' '35']
# ['EFOQOG' '56']
# ['QIGVAD' '83']
# ['SIHPOQ' '120']
# ['LESZIT' '104']
# ['AJASEK' '59']
# ['VADQAU' '106']
# ['GOMXIR' '8']
# ['DEBMOM' '37']
# ['BIXNEB10' '89']
# ['AJODOU' '40']
# ['GLUTAM08' '57']
# ['TICJAS' '84']
# ['NADYUM' '65']
# ['FEHVUK' '33']
# ['EXETEI' '43']
# ['PUNMAO' '100']
# ['HAMJEL' '49']
# ['AMIPYZ' '33']
# ['EKUJIF' '34']
# ['NUPBIL' '32']
# ['VENREN' '53']
# ['FEFNOT08' '112']
# ['ACIDOH' '34']
# ['PIKDAO' '45']
# ['RHODHY' '16']
# ['QETKOP' '135']
# ['GIRRUV' '76']
# ['JUFKIE' '69']
# ['POVKAO' '66']
# ['ZZZRJG01' '45']
# ['DOCNIS' '102']
# ['WOKPAO' '13']
# ['WUXYAQ' '10']
# ['DELMOX' '46']
# ['OHEMAR' '18']
# ['NUZQOO' '74']
# ['FOVYAQ01' '46']
# ['QOWFUF' '60']
# ['HEQWOR' '34']
# ['SIKGIC' '171']
# ['ZENMUA' '45']
# ['COXZAS04' '104']
# ['MIRTOW' '29']
# ['UGECOA' '11']
# ['MPYDCX' '24']
# ['QOXPEZ' '49']
# ['ULIZAS' '13']
# ['ITAFUF' '51']
# ['CEHJIJ' '23']
# ['ZIBBAP' '86']
# ['LUDFOF' '78']
# ['DODCHD' '90']
# ['REZMOY' '81']
# ['ANITOI' '91']
# ['DACLOL' '91']
# ['UHIQOS' '36']
# ['JUPROB' '69']
# ['KEKCEJ' '81']
# ['SIGGUL' '89']
# ['TAPZAN' '31']
# ['KUKHOP' '57']
# ['KABFID' '118']
# ['FAQWEB' '37']
# ['MISGAX' '48']
# ['JOPNOR' '135']
# ['MMCPUR' '45']
# ['RAQVUB' '38']
# ['EKUJIF' '45']
# ['CIWNED' '73']
# ['AMFORM' '15']
# ['KUQQEU' '46']
# ['TAXSOA' '120']
# ['SETFUS' '111']
# ['MEVDAT' '17']
# ['OGIQOL' '24']
# ['VOHCEC' '92']
# ['VEMFEY01' '91']
# ['ROGDIB' '86']
# ['FATZEH' '110']
# ['BIDCEW' '54']
# ['PEBWOI' '115']
# ['QAKCOU' '49']
# ['VAVHEH' '91']
# ['ISIBER' '143']
# ['VOQMOE' '75']
# ['XEPNUD' '84']
# ['GACLEE' '15']
# ['KOBXUU' '57']
# ['BONKOE' '60']
# ['YOKJOY' '94']
# ['JEMFUD' '59']
# ['GEFTES' '10']
# ['TUJWOL' '102']
# ['EXIGOI' '113']
# ['ITIPEG' '10']
# ['VIWYEH' '99']
# ['WOLNIW' '28']
# ['NASQED01' '76']
# ['WURLAY' '19']
# ['KOTWOH' '83']
# ['UHAMOF' '8']
# ['LITRAH' '64']
# ['CTMTNA06' '80']
# ['HESSIH' '67']
# ['ISPADN' '65']
# ['JIXCOI01' '64']
# ['YUFKUF' '32']
# ['CONNID' '14']
# ['CAZDOY' '61']
# ['YUWGOO' '82']
# ['DATQAR' '23']
# ['JUVMUI' '46']
# ['JEFMUD' '31']
# ['AHIHEF' '33']
# ['LINKAW' '59']
# ['YENGOP' '33']
# ['UHAMOF' '17']
# ['DAFWAI' '4']
# ['DUZFUB' '63']
# ['QEYCOM' '48']
# ['NUPVUR' '35']
# ['MAPYNM' '43']
# ['CIKRET' '90']
# ['MINGEX01' '7']
# ['KAVYIP' '83']
# ['PEFGEO01' '97']
# ['VOBDOF' '56']
# ['DIDJUX01' '49']
# ['KULMUA' '41']
# ['NIQPOT02' '61']
# ['PUSYIM' '29']
# ['YEHPIK' '30']
# ['XUHPIB' '95']
# ['NEPBEQ' '36']
# ['UXUYUJ' '105']
# ['RIVKAJ' '29']
# ['HADFEY' '60']
# ['XOPWEF03' '73']
# ['CABCUD15' '77']
# ['EDAJIE' '34']
# ['DAPXEX' '113']
# ['EMOGUJ' '50']
# ['NOACTD' '37']
# ['ACXMPR' '56']
# ['XOVWEK' '10']
# ['PIWDUU' '149']
# ['HALMAJ' '14']
# ['XDHURC' '15']
# ['BUKVAE' '55']
# ['MOWBUX' '18']
# ['CANCIE' '50']
# ['TUNMUL' '72']
# ['GEPRUQ' '34']
# ['DOXHPX' '65']
# ['UJULIU' '44']
# ['UPOCEJ' '68']
# ['GACLEE' '42']
# ['DOMQUS' '55']
# ['LOBHIV' '119']
# ['NUJLUB' '77']
# ['ZAXLIV' '24']
# ['AZETAC' '31']
# ['LANXON' '72']
# ['KAYTUZ' '91']
# ['BOCZIE' '9']
# ['CAFMIF' '18']
# ['KICCOO11' '111']
# ['FEPNAP' '10']
# ['EFUMAU03' '42']
# ['QOLVAP' '15']
# ['GUCDEO' '52']
# ['DUSBUQ' '25']
# ['NIJPEB' '44']
# ['OMEJOG' '22']
# ['DOGQAR' '75']
# ['CINSOH' '85']
# ['QAGDEK' '43']
# ['KEDWEV' '138']
# ['LEJPAS' '98']
# ['ISIBER' '80']
# ['KUQTIB' '64']
# ['LORXOG' '42']
# ['GUBZOS' '147']
# ['BIGUAN' '50']
# ['URAWER' '76']
# ['KOFKEV' '59']
# ['RABQUC' '101']
# ['UNUSED' '96']
# ['WILCOJ' '16']
# ['NUFRUB' '89']
# ['CATNUI' '52']
# ['BIXNEB10' '81']
# ['AMACAM01' '37']
# ['AKEKIL' '47']
# ['VUWKII' '74']
# ['KOVHOS' '144']
# ['DEDWER' '42']
# ['EKUJUR' '14']
# ['BABFUI' '52']
# ['MUYTAC' '4']
# ['KEPFAO' '57']
# ['MOMFAV' '109']
# ['ONOHEF' '18']
# ['AGUSEB' '49']
# ['BANRUE' '39']
# ['YELWES' '96']
# ['BUKJOG10' '36']
# ['GAZGOF' '72']
# ['AMIXPO' '89']
# ['CAFMIF' '14']
# ['JEYNOR' '60']
# ['EFOQOG' '29']
# ['EMOHAQ' '30']
# ['WUNCOZ' '44']
# ['TEDNIB' '44']
# ['KANVAX' '63']
# ['AMTETZ' '5']
# ['DZHPDO' '39']
# ['NIHFAN' '7']
# ['FOACAM' '93']
# ['PICLIX' '74']
# ['KUTHEN' '113']
# ['FIZDIB' '32']
# ['HEWFEW' '101']
# ['CYSTAC08' '46']
# ['SIGBOZ' '53']
# ['IZUGOZ' '69']
# ['DUPDAU' '60']
# ['HAJVOE' '139']
# ['MEMWUW' '58']
# ['KEMHOB' '67']
# ['AMCYTS' '42']
# ['TECNUL' '47']
# ['DAVYAA' '61']
# ['XOZBUK01' '42']
# ['ARCLAM03' '23']
# ['OREHOK' '50']
# ['TUJWOL' '86']
# ['NIWCAY' '8']
# ['NUMRAP' '35']
# ['KACGIG' '48']
# ['OXOFMB' '58']
# ['CBCPIC' '43']
# ['TOBRUX01' '30']
# ['QIPPUA' '101']
# ['TATYAQ' '86']
# ['WASRAJ02' '75']
# ['POQQIW' '127']
# ['FIBWUI' '60']
# ['SIKJIF' '73']
# ['ALIWID' '16']
# ['GLYCIN02' '34']
# ['KECZAU' '8']
# ['FIBGEE' '30']
# ['YUZTET' '49']
# ['RAQROR' '55']
# ['LESLAX' '78']
# ['UFEPAX' '84']
# ['PUTTUU' '131']
# ['MEQPED' '34']
# ['YILPAM' '50']
# ['BUKVAE' '63']
# ['YEKHIH' '54']
# ['DIQCAJ' '40']
# ['EJEHEG' '86']
# ['MAPYNM' '32']
# ['ZEXJAP' '53']
# ['GAVMUM' '60']
# ['XEXVEB' '138']
# ['DAHMII' '66']
# ['KUQTIB' '41']
# ['OXUVUZ' '81']
# ['BUYZAW' '89']
# ['ADOFEF' '52']
# ['ROFFEY' '61']
# ['ATOMAY' '6']
# ['XIQCEF' '105']
# ['SOLLOV02' '7']
# ['FEMMOA' '13']
# ['ZEXYOQ' '68']
# ['HOYMAJ' '80']
# ['CANCIE' '24']
# ['XADPEA' '23']
# ['NOLDOJ01' '58']
# ['BONKOE' '84']
# ['NIVPAJ01' '153']
# ['UQALUU' '76']
# ['COTTAI' '57']
# ['MARQIH' '2']
# ['TARTMM01' '44']
# ['ULIDID' '36']
# ['XIGSIR' '60']
# ['AJUKIZ01' '137']
# ['FUHTAE' '78']
# ['ELULOM' '161']
# ['ISEDOB' '99']
# ['AEBHXM10' '36']
# ['PRONAC02' '17']
# ['EVOZIZ' '103']
# ['CALFOM' '70']
# ['TAXSOA' '91']
# ['ZIKMOV01' '77']
# ['MNPYDO29' '27']
# ['NOCNOK' '33']
# ['KIKNEY' '42']
# ['TURPUR01' '37']
# ['IFIZIG09' '36']
# ['YEKJAB' '58']
# ['JEMSUP' '34']
# ['RESHAY' '63']
# ['DUCYOQ' '31']
# ['GEPRUQ' '75']
# ['QAGRIC' '71']
# ['LIJJIY' '92']
# ['YOTNEB' '57']
# ['TIJLIH' '75']
# ['SAZFIJ' '105']
# ['UPAWEP' '42']
# ['SUYQEK' '50']
# ['ODOHIA' '18']
# ['QIQCUQ' '20']
# ['QURYUZ01' '32']
# ['LEFRAP' '49']
# ['HEJGOU01' '65']
# ['UTALIM' '51']
# ['ACETSC10' '22']
# ['AGEQIO' '91']
# ['MUDDEU' '72']
# ['DEHSAK10' '53']
# ['VABZUV' '59']
# ['VINXEW' '59']
# ['NIQPOT02' '66']
# ['WAKROS' '65']
# ['EROFEX' '71']
# ['CIRXAD' '50']
# ['SEGBUB' '84']
# ['MUCCOD' '131']
# ['EVIJUP' '89']
# ['EREREY' '36']
# ['VAWJEK' '65']
# ['ZIYZOY' '66']
# ['CEHJIJ' '30']
# ['DOZKOS' '83']
# ['KEBGAB02' '54']
# ['FUSJOT' '33']
# ['NEBPUF' '41']
# ['VIPKIO03' '45']
# ['NOFBIT' '60']
# ['FOZLIQ' '19']
# ['FEHDAX01' '97']
# ['HOLQUU' '63']
# ['SENRUZ' '143']
# ['SOJGED01' '48']
# ['FEYTOU' '58']
# ['QOSRUN' '34']
# ['OQAHEV' '33']
# ['SIXYEE' '25']
# ['KEHYAZ' '49']
# ['BUFGAK' '106']
# ['LITRAH' '70']
# ['AJASEK' '77']
# ['FADSAF' '38']
# ['JEMTAW' '52']
# ['LIKYOV' '34']
# ['TORTEZ' '119']
# ['KOVHOS' '184']
# ['JOPNAD' '65']
# ['SATRIO' '100']
# ['QONROC' '37']
# ['OJUMOX' '46']
# ['XUYZIC' '44']
# ['DMTRZT' '41']
# ['SUPFOY' '48']
# ['TURACD' '96']
# ['BUYRUI02' '167']
# ['CAKXAO' '97']
# ['DUMQAF' '58']
# ['JOSXUK' '112']
# ['UPIKUB' '25']
# ['LENBAH' '71']
# ['RALCEN' '20']
# ['GEYSEI' '62']
# ['LANXON' '66']
# ['WECRED' '51']
# ['EYIJAY' '130']
# ['QAGRIC' '135']
# ['DOXKOR' '125']
# ['FIFFIK' '169']
# ['PORQAQ' '109']
# ['XEHDAS' '12']
# ['MUYBAK' '69']
# ['PAZCUO' '66']
# ['UQISOE' '97']
# ['EFITAP' '51']
# ['FONMEB' '66']
# ['NOKXEQ' '111']
# ['LILLEY' '104']
# ['KOFZOW' '23']
# ['UXAZEZ' '49']
# ['TIHQOR' '70']
# ['INEZOS' '31']
# ['KUHDIA' '36']
# ['EVATUR' '40']
# ['JEMTAW' '50']
# ['NIBXOL' '111']
# ['KAXWIQ' '69']
# ['POVKIW' '42']
# ['URAWER' '61']
# ['LIJJIY' '125']
# ['XUHZAD' '96']
# ['ZAQJEI' '29']
# ['GLYGLY17' '52']
# ['GUWPIZ' '31']
# ['TAYHOR' '108']
# ['BEMCAZ' '70']
# ['DOMQUS' '44']
# ['YANSEN' '69']
# ['OFUKOR' '50']
# ['QAGDEK' '46']
# ['CUPZEU' '34']
# ['HEVLUP' '31']
# ['AZASER11' '56']
# ['ZESSOF' '52']
# ['ITIPEG' '144']
# ['SAWMUA' '22']
# ['BOQWUZ' '74']
# ['ACOJAF' '88']
# ['CUPZEU' '46']
# ['LUKNAG' '45']
# ['IVEZEO' '144']
# ['DEXBEN' '34']
# ['VEFMOI' '58']
# ['ULANUS' '51']
# ['UCONIJ' '38']
# ['TACQAP' '53']
# ['FORSAI' '92']
# ['AJASEK' '73']
# ['FORAMO' '8']
# ['PAXTIT' '61']
# ['YOVVIP' '16']
# ['SOJMOT' '51']
# ['QENYOX' '66']
# ['RUNJIV' '45']
# ['TCMPCQ01' '139']
# ['SITQET' '127']
# ['PAZDPY' '43']
# ['YOPKOE' '78']
# ['ALXANM01' '20']
# ['RIYYAA' '32']
# ['SOVNEX' '126']
# ['AJOFUA01' '46']
# ['JUKWIV' '110']
# ['DUMPAC' '72']
# ['DUCYOQ' '55']
# ['XUHZAD' '89']
# ['AMOXAC' '101']
# ['GUMMUW10' '11']
# ['SUNDIQ' '115']
# ['VIWYEH' '70']
# ['CYTOSM12' '39']
# ['ALLCAM' '154']
# ['BZAMID06' '93']
# ['SUCROS27' '85']
# ['LOTYEY' '50']
# ['ECUXOQ' '4']
# ['TEJPEE' '96']
# ['DOZXEW' '34']
# ['FAVMIY' '88']
# ['GORXOA' '128']
# ['ROGQIO' '98']
# ['QOQGOT' '18']
# ['LOSLAI' '55']
# ['YELWES' '38']
# ['TIYLEU' '34']
# ['EXIGAU' '135']
# ['TANCUI' '20']
# ['ODEZEE' '55']
# ['NERJUQ' '97']
# ['WOMYEC' '5']
# ['AJEGUS' '40']
# ['TAWPEN' '76']
# ['ONIVOY' '3']
# ['FOWFII' '26']
# ['RAJDEM' '15']
# ['BANRUE' '51']
# ['ITEGIX01' '68']
# ['EREREY' '56']
# ['CIZSEL' '32']
# ['PINGAW' '184']
# ['GUGJOH' '28']
# ['LAGHOQ' '91']
# ['ILOHIC' '69']
# ['RABVIC' '91']
# ['OKEBAJ' '105']
# ['FECVEP' '92']
# ['QIYRIZ' '23']
# ['GANHUY' '120']
# ['KAGMIO' '44']
# ['DIBGEA01' '36']
# ['HASLIY' '31']
# ['AHICIF01' '17']
# ['MAZMEH' '31']
# ['CREATH04' '42']
# ['MOZWII' '28']
# ['UPONAQ' '49']
# ['TERSEP' '17']
# ['UPONEU' '26']
# ['DEFYUI' '110']
# ['DEKRUG' '88']
# ['QIZBIL' '68']
# ['THYGLY10' '47']
# ['TAPHEY' '63']
# ['COKJOB' '71']
# ['TALSOP' '57']
# ['MOHCUI' '34']
# ['GEXQEF' '102']
# ['CPRDCA' '35']
# ['NEZMUA' '24']
# ['SECMOE' '32']
# ['SESQIR' '56']
# ['CEDHUQ' '12']
# ['VANCIX' '66']
# ['FADCUI' '53']
# ['AFEXUF' '119']
# ['ADEWUC' '75']
# ['VOFDEZ' '80']
# ['PYRDMD' '45']
# ['IKASUK' '34']
# ['PEHXIK' '28']
# ['EMOGUJ' '8']
# ['FOQKIF' '47']
# ['RIHJIB' '158']
# ['ZDGLPN' '135']
# ['XODDUQ' '142']
# ['FADBOB' '93']
# ['VEZNEV' '127']
# ['VAMJOJ' '27']
# ['NADYUM' '22']
# ['WIGBOE' '101']
# ['SIBVUU' '85']
# ['KEPSED' '111']
# ['YOKJOZ' '59']
# ['JIXGUS' '40']
# ['YAGQOM' '58']
# ['IWUGIQ01' '63']
# ['QOWFUF' '90']
# ['HODMOD' '106']
# ['ZEXYOQ' '32']
# ['JEXROT' '20']
# ['BODFEF' '75']
# ['NABMIM' '66']
# ['AFEXUF' '104']
# ['IMEZIL' '55']
# ['SAPXEM' '76']
# ['JUKWIV' '153']
# ['RATGEZ' '36']
# ['JEPPEZ' '96']
# ['TALTIK' '147']
# ['YOTNEB' '83']
# ['UREAOH12' '30']
# ['AZASER11' '74']
# ['GATCAG' '54']
# ['IBPRAC14' '123']
# ['XIDQIL' '27']
# ['VALWIQ' '63']
# ['QAKCOU' '6']
# ['XUYZIC' '62']
# ['JERHIX' '40']
# ['SABMAL' '118']
# ['IJEPOE' '4']
# ['VABZUV' '102']
# ['HUKRUA' '28']
# ['SUYQEK' '30']
# ['WAKSUX' '104']
# ['VICBAK' '110']
# ['FAVMIY' '74']
# ['OKINAY' '16']
# ['TIMBAU' '39']
# ['OJIVOU01' '35']
# ['KESVOT' '75']
# ['XERBEB' '74']
# ['OXAYAO' '129']
# ['ITIXUE01' '112']
# ['OGEGIR' '69']
# ['KOBXUU' '53']
# ['NIWCAY' '25']
# ['OKAVAY' '77']
# ['MESCZA' '21']
# ['ROKTAO' '45']
# ['TIHHOJ' '16']
# ['QUFPEO' '160']
# ['ZZZKAY02' '88']
# ['ZZZRTW01' '88']
# ['VUKRUP' '20']
# ['DALGON03' '80']
# ['UNUSED' '110']
# ['KOBYOP' '50']
# ['BANRUE' '36']
# ['POXYAC' '46']
# ['KUQVOI' '69']
# ['XEHDAS' '23']
# ['SEQVAN' '27']
# ['AKEKIL' '22']
# ['JESNAX' '194']
# ['GAVLUK' '25']
# ['ZOXCIA' '45']
# ['NIMVAG' '35']
# ['GIMREA' '44']
# ['VUBQAM01' '43']
# ['AMPHOM03' '75']
# ['VOSDIQ' '71']
# ['VETQUI' '108']
# ['YODHIJ01' '87']
# ['VUBQAM01' '72']
# ['FEMGIN' '58']
# ['OHUSIV' '61']
# ['GELWOL' '58']
# ['COHWIF01' '46']
# ['CEDSAH' '86']
# ['DICHEC' '63']
# ['PUKGIN' '25']
# ['WIJNEI' '61']
# ['HISTPU' '95']
# ['ZEVJAL' '125']
# ['NOPPOY' '6']
# ['LICROE' '60']
# ['DAYHIV' '8']
# ['VINXEW' '61']
# ['MARQIH' '30']
# ['ZIBBET' '4']
# ['WILCOJ' '14']
# ['VUCBAW' '33']
# ['LETBUH' '80']
# ['RAVFEA' '2']
# ['TAPHEY' '36']
# ['YARZUN03' '18']
# ['YILPAM' '53']
# ['JUKWIV' '94']
# ['QIQCUQ' '14']
# ['GEJCEF' '52']
# ['KEKCEJ' '78']
# ['BUYRUI02' '149']
# ['LEFLUE' '25']
# ['RIZZEH' '115']
# ['BODSAO' '74']
# ['FEZRAD' '70']
# ['KOFKEV' '73']
# ['GLYCIN62' '14']
# ['SAPXEM' '48']
# ['GENZEF' '55']
# ['SITQET' '97']
# ['LUNYID' '32']
# ['HATWII' '97']
# ['OXUVUZ' '37']
# ['XEJYAN' '8']
# ['CEDKON' '122']
# ['SAZFIJ' '54']
# ['GAFWIV' '128']
# ['DXSDMO' '102']
# ['ONIVOY' '49']
# ['QOWFUF' '148']
# ['SALMID05' '133']
# ['ANOTAZ' '18']
# ['YASSIV' '26']
# ['ADOFEF' '81']
# ['AFEXUF' '70']
# ['PAGVAU' '92']
# ['AGAWIQ' '11']
# ['AHIHEF' '23']
# ['VOPTOL' '12']
# ['PORXUQ' '83']
# ['KIXWIZ' '49']
# ['OXOFMB' '53']
# ['ZIBBAP' '124']
# ['JERHIX' '48']
# ['LEPMID' '111']
# ['VIWCOT' '51']
# ['MOHCUI' '49']
# ['SOBBOA' '100']
# ['SOZHUM' '25']
# ['FOYGOR' '63']
# ['ZIYZEM' '112']
# ['LSERMH15' '65']
# ['EREREY' '47']
# ['AMBNAC04' '28']
# ['KAKQAO' '50']
# ['RAMVUW' '32']
# ['LICROE' '39']
# ['NADHOP01' '25']
# ['HAMJEL' '39']
# ['RIWTIB01' '10']
# ['YARYAS' '97']
# ['DZCDON' '18']
# ['CYSTAC08' '74']
# ['ASOTIL' '121']
# ['HAJXIB' '96']
# ['TAHNEV' '113']
# ['YOGJUB' '82']
# ['QONROC' '39']
# ['TIBMUM' '98']
# ['LSERIN12' '38']
# ['QUCGEC' '83']
# ['NADMUA' '114']
# ['ACACOX' '44']
# ['GUGJOH' '46']
# ['LUDFAR' '48']
# ['FEMCEF' '40']
# ['EDAJIE' '38']
# ['HOBXEC' '47']
# ['NOPQIT' '78']
# ['KATKIA' '98']
# ['VIHTUD' '10']
# ['QEPFIB' '59']
# ['ACAMOX' '8']
# ['MIMMEB' '47']
# ['FIWYUF' '154']
# ['YIFVAL' '23']
# ['AGAWIQ' '36']
# ['VEYVOK' '27']
# ['DOLLEV' '58']
# ['GIZSOX' '124']
# ['ETTHUR04' '10']
# ['WEPPUE' '47']
# ['GOLDIV' '106']
# ['VIOLME05' '18']
# ['GILZUW' '74']
# ['NAYKOO' '108']
# ['XOJQUK' '34']
# ['CBOHAZ04' '21']
# ['LCYSTN25' '30']
# ['EFITAP' '68']
# ['UNEVOZ01' '171']
# ['HMBQOX10' '37']
# ['XOHXUP' '29']
# ['XESRIW' '41']
# ['QAFFIM' '17']
# ['AMOXAM' '14']
# ['KEPFUI' '66']
# ['UTUVAI' '141']
# ['MEVDAT' '98']
# ['CAXNIY' '101']
# ['JOWSOD' '73']
# ['TAJHOB' '141']
# ['WAWWAU' '57']
# ['DOHDEJ' '72']
# ['DANJEH' '78']
# ['GEZXAK' '87']
# ['WIHJAZ' '41']
# ['GAUTAM15' '55']
# ['AHIMOU' '103']
# ['SAWNAH' '52']
# ['GUSVOH' '5']
# ['FORMAM03' '33']
# ['JUXHUF' '34']
# ['QAHCUA' '45']
# ['UMIXIZ' '47']
# ['TENZOD' '54']
# ['AJAJEA' '28']
# ['LEVXOB' '16']
# ['NIFDAI' '81']
# ['NMHXNT' '77']
# ['CALVAM' '69']
# ['UNOKIR' '126']
# ['UNOKIR' '102']
# ['DAYQEZ' '134']
# ['WIDJOI' '134']
# ['DIXYUE01' '62']
# ['KUZWUY' '32']
# ['URACIL' '19']
# ['LAQDUE' '17']
# ['DAPJUA' '163']
# ['NOLDOJ01' '6']
# ['BOBCUO' '122']
# ['AHUFUF' '46']
# ['XARBAV' '64']
# ['TALTIK' '37']
# ['LENBAH' '97']
# ['LOBHIV' '132']
# ['LAYYUH' '145']
# ['JOSXUK' '150']
# ['IJEPOE' '37']
# ['OVAYAM' '141']
# ['ROBYAI' '86']
# ['CALFOM' '51']
# ['MUKVUJ' '94']
# ['RUJNOA' '31']
# ['ULIZAS' '70']
# ['TANPEE' '31']
# ['ITIWIT' '14']
# ['BEKBOI' '63']
# ['ISEBUD' '56']
# ['XIHLIL' '45']
# ['BEMCAZ' '63']
# ['HAJXIB' '111']
# ['KUTHEN' '103']
# ['LADLOT' '91']
# ['VOHXIB' '165']
# ['DIDFAY' '155']
# ['VOFVAN23' '51']
# ['DIXYUE01' '66']
# ['BEPNIT' '39']
# ['NMALAM01' '36']
# ['UNEWUG' '138']
# ['HIVLAA' '39']
# ['SAFYIK' '130']
# ['FUZYUU' '54']
# ['CDECOL11' '95']
# ['BIDCEW' '56']
# ['TIMFUS' '103']
# ['APENIU' '121']
# ['NADREN' '51']
# ['HISTPU' '81']
# ['COVXAN01' '48']
# ['SADCUV' '118']
# ['TIWHAK' '100']
# ['DIDXOE' '69']
# ['XATZAT' '46']
# ['RICFIS' '83']
# ['UXUKII' '39']
# ['KUTHEN' '131']
# ['OKINAY' '100']
# ['UFUXOI' '41']
# ['LIFNOE' '41']
# ['XOHXUP' '11']
# ['XUDQUJ' '24']
# ['REVMIP' '33']
# ['LUVTOL' '30']
# ['GIVFIC' '44']
# ['ARAQUH' '19']
# ['GAZGOF' '117']
# ['YOWLUS' '83']
# ['CANCIE' '18']
# ['CABCUD15' '38']
# ['FUWPUK' '73']
# ['VINXEW' '34']
# ['PULGOU' '40']
# ['YEKHIH' '38']
# ['METACM02' '37']
# ['CMPDZB' '120']
# ['COKXUX' '78']
# ['PUTTUU' '53']
# ['IJETOG02' '129']
# ['CASYIG' '103']
# ['ZEBYEM' '16']
# ['DHURAC10' '37']
# ['IFAYIZ' '36']
# ['MEVDAT' '92']
# ['WIKBAT' '68']
# ['SIKGIC' '172']
# ['EDAJIE' '12']
# ['KOVHOS' '175']
# ['FACVUB' '67']
# ['ACERUX' '41']
# ['BCBANN02' '27']
# ['ZEXKEU' '28']
# ['FUVDOP' '102']
# ['GIRRUV' '59']
# ['YUZTET' '51']
# ['TUMZAE' '13']
# ['DAVARO' '69']
# ['WOGFAZ' '43']
# ['WEWRAR' '77']
# ['LORJAD' '145']
# ['DIDXOE' '32']
# ['HUKGOJ' '37']
# ['KUTHAI' '103']
# ['AMTHTZ' '24']
# ['ARADEN10' '70']
# ['PAMGIW' '47']
# ['SOVZAE' '118']
# ['KIWJIK' '91']
# ['FIPZIN01' '45']
# ['LICLEP01' '66']
# ['HOFLAQ01' '89']
# ['LUMJOU' '85']
# ['ZOBYAQ' '61']
# ['KACGIG' '87']
# ['WERHUX' '41']
# ['CROTAC' '71']
# ['AMOXAM' '45']
# ['OGIQEB' '75']
# ['CUTWIX' '153']
# ['DUKWUB' '35']
# ['OGIQOL' '6']
# ['ODENOB' '29']
# ['EZIYES' '142']
# ['EBUKOB' '87']
# ['FUSFAB' '74']
# ['OGAJOV' '51']
# ['UGECOA' '6']
# ['CAGJEC01' '55']
# ['SOCGUM' '134']
# ['QIRRUG' '53']
# ['PHGLOL01' '14']
# ['BOQQUT08' '63']
# ['YUZTET' '57']
# ['OHAHAI' '99']
# ['PUJZEA' '82']
# ['GLUTAM08' '63']
# ['LAQSOM' '2']
# ['HAMJEL' '108']
# ['UFAWUV' '20']
# ['DOBPIV' '27']
# ['FOVVUI' '47']
# ['FADBOB' '108']
# ['PUKDUV01' '78']
# ['FOLVIL' '58']
# ['UMERAF' '89']
# ['DOKQIE' '10']
# ['LUMJOU' '22']
# ['VINXEW' '27']
# ['SETFUS' '125']
# ['SERMUZ' '101']
# ['VOHXIB' '35']
# ['VUGMIV' '165']
# ['PIDHIU' '36']
# ['XOSJUK' '34']
# ['DEKRUG' '100']
# ['POVKAO' '79']
# ['JIWZAQ' '113']
# ['CIFROY' '70']
# ['UMOBAB' '189']
# ['PONNIQ' '9']
# ['WETGAE' '13']
# ['COKJER' '147']
# ['OXOGEO' '78']
# ['KUTHEN' '155']
# ['NOLDUP' '137']
# ['CUTTOB' '52']
# ['ZZZKAY02' '61']
# ['LESJAV' '88']
# ['IKANUE' '89']
# ['HIVLAA' '42']
# ['DOZXEW' '22']
# ['BUFMOG' '42']
# ['ZILNOX01' '40']
# ['POWBEI' '111']
# ['MSORAM10' '64']
# ['HOBXEC' '29']
# ['EBIROX' '74']
# ['BOCZIE' '89']
# ['VOBDOF' '143']
# ['NSBTOA' '55']
# ['VECXIL' '7']
# ['BCBDNT' '38']
# ['ECAGIA' '21']
# ['VICREE' '44']
# ['DEHYUM' '52']
# ['CAKRIQ' '24']
# ['ZAXLIV' '22']
# ['NESFIA' '58']
# ['ACOTHI' '50']
# ['YANVUG' '47']
# ['OKEBAJ' '77']

# %%
PATH_TEST = "./make_tensor_data/test_tensor/CSD-500+104-7_shift_tensors.xyz"

structures_test = read(PATH_TEST,format="extxyz",index=":100")

for structure in structures_test: mask_center_atoms_by_species(structure,species_select=[1])
for structure in structures_test: structure.wrap(eps=1e-12)

# %%
shifts_test = np.array([tensor for structure in structures_test for tensor in structure.arrays["cs_iso"][structure.arrays["center_atoms_mask"]]])

# %%
shifts = np.array([tensor for structure in structures_train for tensor in structure.arrays["cs_tensor"][structure.arrays["center_atoms_mask"]]])

# %%
shifts.shape
# Out:
# (3868, 9)

# %%
hypers = dict(soap_type="PowerSpectrum",
              interaction_cutoff=4.5,
              max_radial=8,
              max_angular=5,
              gaussian_sigma_constant=0.3,
              gaussian_sigma_type="Constant",
              cutoff_function_type="RadialScaling",
              cutoff_smooth_width=0.5,
              cutoff_function_parameters=
                    dict(
                            rate=1,
                            scale=3.0,
                            exponent=6
                        ),
              radial_basis="GTO",
              normalize=True,
              optimization=
                    dict(
                            Spline=dict(
                               accuracy=1.0e-05
                            )
                        ),
              compute_gradients=False
              )

hypers = get_optimal_radial_basis_hypers(hypers, structures_train, expanded_max_radial=20)

# %%
calculator = SphericalInvariants(**hypers)

# %%
X_train = calculator.transform(structures_train).get_features(calculator)

# %%
X_test = calculator.transform(structures_test).get_features(calculator)

# %%
X_test.shape
# Out:
# (35289, 5760)

# %%
from skcosmo.feature_selection import PCovFPS

# %%
selector = PCovFPS(
                    n_to_select=500,
                    progress_bar=True,
                    score_threshold=1e-12,
                    full=False,

                    # float, default=0.5
                    # The PCovR mixing parameter, as described in PCovR as alpha
                    mixing = 0.5,

                    # int or 'random', default=0
                    # Index of the first selection.
                    # If ‘random’, picks a random value when fit starts.
                    initialize = 0,
                    )
selector.fit(X_train, shifts)
# Out:
#   0%|          | 0/499 [00:00<?, ?it/s]
# PCovFPS()

# %%
selector.selected_idx_
# Out:
# array([   0,  768,  384, 1536, 2366,  385,    1,  780,  392, 1537, 1215,
#        1538, 1164, 3122,   54, 3457, 2743, 1926, 1172, 1167, 2304,  784,
#        1201, 2310,  830,  769,   96, 1152, 2000,    6, 3456, 2016,  808,
#        1932,  774, 3460,    2,  831, 1169,  817, 1320, 2688, 1302, 1401,
#         776, 3513,  929, 1176,    5,  781, 1591,  802, 1206,  881, 2799,
#         876, 1170, 1161, 1592, 3135,  915, 1158, 3072,    4,  388,  393,
#        3461,  400,  924, 1219, 1940, 1306,  391, 1956,  804, 1541,  108,
#        2740,  771,  112, 2358,  822, 3568,   59, 1228,  816,  109, 1226,
#        1646,   18,  531,  394, 1494, 2558, 2074, 1701, 1250,  390,  462,
#        1173, 2747, 1925, 1180,  962, 2411, 1700, 1162,  926, 1223, 2073,
#        2361, 1194, 1398, 1200, 1263,   57, 1207, 1920,  931, 1297, 1165,
#         415,  965, 1969, 2400, 3272, 2692, 3140,   58, 3121,  396,  486,
#        2360, 2067,    3, 1971, 1977,  726, 1153, 3561,  442,  534, 1220,
#        2114, 1645, 2359, 1944, 2507, 2353, 1209, 2457, 1256, 2001,  412,
#        2166,   24, 1974, 3223, 3459,  871, 2850, 2352,  445,  386, 3226,
#         810,  489, 2563,  807,  414, 1972,  773, 1202, 1590, 1249, 1952,
#        3081, 2744, 2041, 1593,  336,  499, 1975, 1258, 2689, 2755, 1539,
#        3128, 1594, 2406, 3096, 2853,  783, 1269,  790,  440, 1540, 1230,
#         441, 2161,  870,  401,  848, 3170,  835, 3569, 2745, 2113,  841,
#        3174, 2025,  463, 1354, 2421, 1595, 2017, 1649, 1010,   56,   55,
#        3127, 2112, 1205, 2800,  438, 3178, 1314, 2691, 3266, 1058, 1236,
#        1261,  448, 1992,  792, 2354, 1318, 1999, 1380, 1981, 3475, 1976,
#         166,  505,  437, 2742, 1116, 1927, 2797, 2376, 1296, 2327,  398,
#        2392,  480,  501, 1949, 1937, 3222, 3077,  492,  798,  435,  978,
#         864,  405, 1988, 1259,  439, 3553,  588, 1968, 1933, 1399,  919,
#         488, 1278, 2382, 3218,  546, 1303, 2450,  497, 2455, 1978,  795,
#         865, 2002, 3746, 1441, 2134, 3230,  612, 2550, 2985, 2418,  464,
#        2316, 1938, 1350,  402, 1248, 3611, 2122, 2072, 1186, 3225,  913,
#         794, 1171, 3082,  102,  528,   63, 1644, 1272,  584,  624, 1270,
#        1264,  583,  866, 3176, 1175,  935, 3098,  844, 3563, 3087, 2834,
#        3095,  793, 3512, 1182, 2477, 1993, 2096,  288, 1942,  408, 2323,
#         678,  450, 1698, 2018, 1198,  432, 3320,  782, 1072, 3134, 2453,
#         823, 2328,  936,   51,  431, 2887, 2404, 2704, 1954, 1305,  457,
#        1458, 2693, 1255,   10, 1703, 1363,  839, 1358, 1928,   13, 2043,
#         517, 3567, 2473,  829, 3103,  297, 2021, 1015,  592,  446, 2064,
#        1656, 3621, 1316, 2028, 1154,  403,  918,  533,  516,  163, 1989,
#        1930, 2703, 3172, 2592,  961,  110, 1393, 1355, 3094, 3510, 2129,
#        2080,  825, 1177,  515,   64,  587, 3458, 1924,  530, 1157, 3123,
#        3265, 3565, 1168,  852,  824,  883, 3136, 2852, 2367, 3482, 2311,
#        1325,  879,  436, 1951, 3130, 2362, 1163, 2087,  420, 3097,  216,
#          98, 2027, 1394,  482,  485, 3560, 1980, 3187,  914, 2379,  514,
#        1218, 3147, 1312, 3462, 1960, 1059, 1322, 1213,  537, 2460, 2339,
#        2523, 1994,  775,  529, 2415,  679, 3120, 2417, 3086,  433, 1996,
#        2416, 3526,  518, 2857, 1188, 1304, 2449,  842,  395, 3318, 3245,
#        3156, 2071,  451,  124, 1212,  779,  174, 1392, 1950, 2054,  473,
#        2413, 1181, 2427, 1193, 2690])

# %%
from sklearn.kernel_approximation import Nystroem

# %%
feature_map_nystroem = Nystroem(kernel="linear",
                                n_components=5000)

# %%
selected_idx_ = np.load("selected_sample_ids_H_n8_l5_PASSING.npy")

# %%
KNM = X_train @ X_train[selected_idx_].T

# %%
from sklearn.linear_model import RidgeCV

# %%
clf = RidgeCV(alphas=np.logspace(-8,3,15)).fit(KNM, shifts)

# %%
KTM = (X_test @ X_train[selected_idx_].T)

# %%
y_pred = clf.predict(KTM)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred,shifts_test,squared=False)
# Out:
# 0.5901255807888104

# %%
X_train[selector.selected_idx_].shape
# Out:
# (5000, 5760)

# %%
np.save("selected_sample_ids_H_n8_l5_PASSING",selector.selected_idx_)

# %%
def build_structure_dict(PATH):
    """Builds a dictionary from an extended xyz file 
    containing key: CSD-NAME value: atoms object pairs
    """
    extxyz = read(PATH,format="extxyz",index=':')
    status_dict = {atom.info["NAME"]: atom for atom in extxyz}
    return status_dict
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-16-c7000bea82ac> in <module>
#      18                     tolerance=1E-12,
#      19                     )
# ---> 20 selector.fit(X_train, shifts)
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/skcosmo/_selection.py in fit(self, X, y, warm_start)
#     188             self._continue_greedy_search(X, y, n_iterations)
#     189         else:
# --> 190             self._init_greedy_search(X, y, n_iterations)
#     191
#     192         n_iterations -= self.n_selected_
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/skcosmo/_selection.py in _init_greedy_search(self, X, y, n_to_select)
#     672         else:
#     673             self.y_current_ = None
# --> 674         self.pi_ = self._compute_pi(self.X_current_, self.y_current_)
#     675
#     676         super()._init_greedy_search(X, y, n_to_select)
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/skcosmo/_selection.py in _compute_pi(self, X, y)
#     753
#     754         if self._axis == 0:
# --> 755             pcovr_distance = pcovr_kernel(
#     756                 self.mixing,
#     757                 X,
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/skcosmo/utils/_pcovr_utils.py in pcovr_kernel(mixing, X, Y, **kernel_params)
#     233     """
#     234
# --> 235     K = np.zeros((X.shape[0], X.shape[0]))
#     236     if mixing < 1:
#     237         K += (1 - mixing) * Y @ Y.T
#
# MemoryError: Unable to allocate 135. GiB for an array with shape (134692, 134692) and data type float64

# %%
train_structures[0].info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-cb70cdc488b2> in <module>
# ----> 1 train_structures[0].info
#
# NameError: name 'train_structures' is not defined

# %%
train_struct_nice = train_structures[:100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-86a3de4c53fd> in <module>
# ----> 1 train_struct_nice = train_structures[:100]
#
# NameError: name 'train_structures' is not defined

# %%
y_pred
# Out:
# array([26.23856941, 26.23859742, 26.23857163, ..., 23.92599114,
#        23.92454931, 23.92598499])

# %%
shifts_test
# Out:
# array([25.97, 25.97, 25.97, ..., 23.13, 23.13, 23.13])

# %%
import tqdm
from nice.blocks import *
from nice.utilities import *

# %%
indices = np.arange(len(structures_train))
indices = np.random.permutation(indices)
indices = indices[:200]

# %%
train_struct_nice = [structures_train[ind] for ind in indices]

# %%
structures_train
# Out:
# [Atoms(symbols='N4O4C20H20', pbc=True, cell=[13.564047596, 5.79502231063, 5.60401339238], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C18H36N8O8', pbc=True, cell=[[7.131018008, 0.0, 0.0], [-3.35710500272, 9.26783468512, 0.0], [-2.0474364974, -1.27908356908, 9.61766816655]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C28H16N32O32', pbc=True, cell=[[12.722757232, 0.0, 0.0], [0.0, 11.8045558426, 0.0], [-0.879600543992, 0.0, 8.09690265277]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C64H118N14O4', pbc=True, cell=[[6.71344207, 0.0, 0.0], [-0.499359248051, 7.71360395615, 0.0], [-1.05722614374, -2.25817365532, 31.890877292]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C32H32N16O16', pbc=True, cell=[[13.24907966, 0.0, 0.0], [0.0, 11.1910736183, 0.0], [-0.519960131257, 0.0, 6.25747407802]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C40H28O18', pbc=True, cell=[[12.009052166, 0.0, 0.0], [-1.92628799458, 9.96557984038, 0.0], [-0.271476633265, -1.38315459227, 7.68991249113]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C40H40N24O32', pbc=True, cell=[9.092423678, 11.8043299642, 12.7518332508], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C80H80N16O20', pbc=True, cell=[8.32902861, 12.920047483, 18.1990607773], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C48H48O12', pbc=True, cell=[[8.550067096, 0.0, 0.0], [0.0, 15.6651251309, 0.0], [-4.01069112359, 0.0, 7.38984864127]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C24H
center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C28H28N4O8', pbc=True, cell=[[7.095033768, 0.0, 0.0], [0.0, 7.64803488995, 0.0], [-0.32618708245, 0.0, 12.0546468427]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C12H44N12O20', pbc=True, cell=[[5.720806226, 0.0, 0.0], [0.0, 7.91440932772, 0.0], [-3.53266649423, 0.0, 17.085628296]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C48H56N8', pbc=True, cell=[[21.720828116, 0.0, 0.0], [0.0, 5.78892650534, 0.0], [-1.60162870279, 0.0, 8.16737890487]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C16H16N32O56', pbc=True, cell=[[11.820081988, 0.0, 0.0], [0.0, 6.16204514198, 0.0], [-1.93709867636, 0.0, 18.1259066073]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='O4N2C4H10', pbc=True, cell=[[5.14601091, 0.0, 0.0], [-0.990025600942, 5.2647345277, 0.0], [-1.77618168766, -2.07608605749, 6.60415368539]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='N4O12C4H12N4H8N4H8', pbc=True, cell=[[3.77940356, 0.0, 0.0], [0.0, 11.3418124516, 0.0], [-1.75404764802, 0.0, 10.9680407777]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C2H4N8', pbc=True, cell=[[4.931005076, 0.0, 0.0], [0.0, 6.4510071147, 0.0], [-2.42099035518, 0.0, 4.8156984533]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C2H6C2H6C6N2H4N10O12', pbc=True, cell=[[8.484025432, 0.0, 0.0], [0.0, 6.14421605811, 0.0], [-1.72838262906, 0.0, 9.27943675235]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C8N12O16H4', pbc=True, cell=[[4.99704674, 0.0, 0.0], [0.0, 18.1911689995, 0.0], [-0.836855417548, 0.0, 5.0440989321]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C28H28N4O8', pbc=True, cell=[[10.183328248, 0.0, 0.0], [0.0, 4.97661288145, 0.0], [-4.86093027256, 0.0, 12.0688020231]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C20H32N8O4', pbc=True, cell=[[7.243045414, 0.0, 0.0], [0.0, 6.99014724032, 0.0], [-2.76986369809, 0.0, 10.9223314082]], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  Atoms(symbols='C24H44N4O16', pbc=True, cell=[7.804029132, 14.6710518982, 6.23602018671], center_atoms_mask=..., cs_iso=..., cs_tensor=...),
#  ...]

# %%
len(train_struct_nice)
# Out:
# 200

# %%
def get_nice():
    return StandardSequence([
        StandardBlock(ThresholdExpansioner(num_expand=150),
                      CovariantsPurifierBoth(max_take=10),
                      IndividualLambdaPCAsBoth(n_components=50),
                      ThresholdExpansioner(num_expand=300, mode='invariants'),
                      InvariantsPurifier(max_take=50),
                      InvariantsPCA(n_components=200)),
        ],
                            initial_scaler=InitialScaler(
                                mode='signal integral', individually=True))

# %%
all_species = get_all_species(train_struct_nice)

# %%
all_species
# Out:
# array([ 1,  6,  7,  8, 16])

# %%
hypers_nice = dict(
              interaction_cutoff=4.5,
              max_radial=12,
              max_angular=9,
              gaussian_sigma_constant=0.3,
              gaussian_sigma_type="Constant",
              cutoff_function_type="RadialScaling",
              cutoff_smooth_width=0.5,
              cutoff_function_parameters=
                    dict(
                            rate=1,
                            scale=3.0,
                            exponent=6
                        ),
              radial_basis="GTO",
              optimization=
                    dict(
                            Spline=dict(
                               accuracy=1.0e-05
                            )
                        ),
              compute_gradients=False
              )


train_coefficients = get_spherical_expansion(train_struct_nice, hypers_nice,
                                             all_species)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# 100%|██████████| 5/5 [00:00<00:00, 25.58it/s]

# %%
train_coefficients[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e0774f9eaba> in <module>
# ----> 1 train_coefficients[1]
#
# NameError: name 'train_coefficients' is not defined

# %%
nice = {}
nice[1] = get_nice()

# %%
train_coefficients[1].shape
# Out:
# (7435, 60, 10, 19)

# %%
nice[1].fit(train_coefficients[1][:1000])
# Out:
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/compressors.py:216: UserWarning: Amount of provided data is less than the desired one to fit PCA. Number of components is 200, desired number of environments is 2000, actual number of environments is 1000.
#   warnings.warn(("Amount of provided data is less "

# %%
train_features = {}

train_features[1] = nice[1].transform(
        train_coefficients[1], return_only_invariants=True)
# Out:
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/miscellaneous.py:137: RuntimeWarning: overflow encountered in square
#   result = 1.0 / np.sqrt(np.sum(coefficients[:, :, 0, 0]**2, axis=1))
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/miscellaneous.py:194: RuntimeWarning: overflow encountered in square
#   return Data(even_coefficients,
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/miscellaneous.py:195: RuntimeWarning: overflow encountered in square
#   even_coefficients_sizes), Data(odd_coefficients,
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/expansioners.py:151: RuntimeWarning: overflow encountered in square
#   return Data(new_even,
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/expansioners.py:152: RuntimeWarning: overflow encountered in square
#   new_even_actual_sizes), Data(new_odd,
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-592955682570> in <module>
#       1 train_features = {}
#       2
# ----> 3 train_features[1] = nice[1].transform(
#       4         train_coefficients[1], return_only_invariants=True)
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/grouping.py in transform(self, coefficients, return_only_invariants)
#     336         all_odd_covariants = [data_odd_0]
#     337         for i in range(len(self.blocks_)):
# --> 338             data_even_now, data_odd_now, invariants_even_now = self.blocks_[
#     339                 i].transform(data_even_now, data_odd_now, data_even_0,
#     340                              data_odd_0, all_even_covariants,
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/grouping.py in transform(self, first_even, first_odd, second_even, second_odd, old_even_covariants, old_odd_covariants, old_even_invariants)
#     194
#     195         if (self.covariants_pca_ is not None):
# --> 196             transformed_even, transformed_odd = self.covariants_pca_.transform(
#     197                 transformed_even, transformed_odd)
#     198
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/compressors.py in transform(self, data_even, data_odd)
#     169                 ("instance of {} is not fitted. "
#     170                  "It can not transform anything.").format(type(self).__name__))
# --> 171         return self.even_pca_.transform(data_even), self.odd_pca_.transform(
#     172             data_odd)
#     173
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/nice/blocks/compressors.py in transform(self, data)
#     137         for lambd in range(self.l_max_ + 1):
#     138             if self.pcas_[lambd] is not None:
# --> 139                 now = self.pcas_[lambd].transform(
#     140                     data.covariants_[:, :data.actual_sizes_[lambd], lambd, :],
#     141                     lambd)
#
# nice/unrolling_individual_pca.pyx in nice.unrolling_individual_pca.UnrollingIndividualPCA.transform()
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/sklearn/decomposition/_truncated_svd.py in transform(self, X)
#     251         """
#     252         check_is_fitted(self)
# --> 253         X = self._validate_data(X, accept_sparse=["csr", "csc"], reset=False)
#     254         return safe_sparse_dot(X, self.components_.T)
#     255
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
#     562             out = X
#     563         elif no_val_X and not no_val_y:
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# /ssd/scratch/kellner/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
train_coefficients.keys()
# Out:
# dict_keys([1, 6, 7, 8, 16])

# %%
train_features[1][2].shape
# Out:
# (7435, 200)
